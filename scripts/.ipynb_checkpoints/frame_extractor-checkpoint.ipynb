# %%
# import helper functions
import os
import json
from contextlib import closing
from videosequence import VideoSequence

# helper functions

# https://stackoverflow.com/questions/17060039/split-string-at-nth-occurrence-of-a-given-character
def splitn(string, spliton, n):
    """split 'string' on nth occurence of 'spliton'
    """
    groups = string.split(spliton)
    return spliton.join(groups[:n]), spliton.join(groups[n:])

# %%
projectroot = "/home/nchhibbe/sketchbook/typealike"
filepath = "/log/one/"
pidentifier = "Test01_experiment_2018-09-03-04-16-16.txt"

# open the output datafile and write the column headers
data = open(projectroot+'/training/videoframes_'+pidentifier[:-4]+'.csv', 'w')
# data.write(','.join(columns) + '\n')

firstTimestamp=0
firstFrameVisited=False
flag=False
currentGetsure=""
videoframes={}
count=0
with open(projectroot+filepath+pidentifier) as f:
    content = f.readlines()

for line in content:
    if line[0] == '#':
        continue
    r = line.strip().split(',')
    if r[1] != "M":
        if r[1] == "E" and r[2]=="trial":
            rr = splitn(line, ',', 3)
            ed = json.loads(rr[1])
            if ed["type"]=="start" and ed["targetType"]=="gesture":
                flag=True
                currentGesture=ed["label"]
            elif ed["type"]=="end" and ed["targetType"]=="gesture":
                flag=False
        else:
            continue
    if not firstFrameVisited:
        firstTimestamp = r[0]
        firstFrameVisited = True;
    if flag:
        datarow = (str(int(30*(int(r[0])-int(firstTimestamp))/1000)),currentGesture)
#         print(datarow)
        videoframes[datarow[0]]=datarow[1]
#         videoframes.append(datarow)
        datarow_csv = ",".join(datarow)
        data.write(datarow_csv + '\n')
    count+=1
data.close()

# %%
directory = projectroot+"/training/"+pidentifier[:-4]
gestureclasses = ["lefthandlock", "righthandlock", "bothhandlock", "lefthandpinch", "righthandpinch", "bothhandpinch", "bothhandcover", "lefthandfist", "righthandfist", "bothhandfist", "upperlefthandlock", "upperrighthandlock", "upperbothhandlock", "birdhand"];
try:
    if not os.path.exists(directory):
        os.makedirs(directory)
        for gesturedir in gestureclasses:
            os.makedirs(directory+"/"+gesturedir)
except OSError:
    print ('Error: Creating directory. ' +  directory)

# %%
videofile = projectroot+"/videos/one/"+pidentifier[:-4]+".mp4"
flag = True
programCounter = 0 # iterator for videoframes
with closing(VideoSequence(videofile)) as frames:
    for idx, frame in enumerate(frames[0:]):
#         if programCounter+1 == len(videoframes):
#             break
#         print(str(idx))
        if str(idx) in videoframes.keys():
            frame.save("../training/"+videoframes[str(idx)][:-4]+"/"+pidentifier[:]+"_frame_"+str(idx)+".jpg")
            flag=False

# %%
videoframes
# Out:
# {'397': 'lefthandlock.png',
#  '398': 'lefthandlock.png',
#  '399': 'lefthandlock.png',
#  '400': 'lefthandlock.png',
#  '401': 'lefthandlock.png',
#  '402': 'lefthandlock.png',
#  '403': 'lefthandlock.png',
#  '404': 'lefthandlock.png',
#  '405': 'lefthandlock.png',
#  '406': 'lefthandlock.png',
#  '407': 'lefthandlock.png',
#  '408': 'lefthandlock.png',
#  '409': 'lefthandlock.png',
#  '410': 'lefthandlock.png',
#  '411': 'lefthandlock.png',
#  '412': 'lefthandlock.png',
#  '413': 'lefthandlock.png',
#  '414': 'lefthandlock.png',
#  '415': 'lefthandlock.png',
#  '416': 'lefthandlock.png',
#  '417': 'lefthandlock.png',
#  '418': 'lefthandlock.png',
#  '419': 'lefthandlock.png',
#  '420': 'lefthandlock.png',
#  '421': 'lefthandlock.png',
#  '422': 'lefthandlock.png',
#  '423': 'lefthandlock.png',
#  '424': 'lefthandlock.png',
#  '425': 'lefthandlock.png',
#  '426': 'lefthandlock.png',
#  '427': 'lefthandlock.png',
#  '428': 'lefthandlock.png',
#  '429': 'lefthandlock.png',
#  '430': 'lefthandlock.png',
#  '431': 'lefthandlock.png',
#  '432': 'lefthandlock.png',
#  '433': 'lefthandlock.png',
#  '434': 'lefthandlock.png',
#  '435': 'lefthandlock.png',
#  '436': 'lefthandlock.png',
#  '437': 'lefthandlock.png',
#  '438': 'lefthandlock.png',
#  '439': 'lefthandlock.png',
#  '440': 'lefthandlock.png',
#  '441': 'lefthandlock.png',
#  '442': 'lefthandlock.png',
#  '443': 'lefthandlock.png',
#  '444': 'lefthandlock.png',
#  '445': 'lefthandlock.png',
#  '446': 'lefthandlock.png',
#  '447': 'lefthandlock.png',
#  '448': 'lefthandlock.png',
#  '449': 'lefthandlock.png',
#  '450': 'lefthandlock.png',
#  '451': 'lefthandlock.png',
#  '452': 'lefthandlock.png',
#  '453': 'lefthandlock.png',
#  '454': 'lefthandlock.png',
#  '455': 'lefthandlock.png',
#  '456': 'lefthandlock.png',
#  '457': 'lefthandlock.png',
#  '458': 'lefthandlock.png',
#  '459': 'lefthandlock.png',
#  '460': 'lefthandlock.png',
#  '461': 'lefthandlock.png',
#  '462': 'lefthandlock.png',
#  '463': 'lefthandlock.png',
#  '464': 'lefthandlock.png',
#  '465': 'lefthandlock.png',
#  '466': 'lefthandlock.png',
#  '467': 'lefthandlock.png',
#  '468': 'lefthandlock.png',
#  '469': 'lefthandlock.png',
#  '470': 'lefthandlock.png',
#  '471': 'lefthandlock.png',
#  '472': 'lefthandlock.png',
#  '473': 'lefthandlock.png',
#  '474': 'lefthandlock.png',
#  '475': 'lefthandlock.png',
#  '476': 'lefthandlock.png',
#  '477': 'lefthandlock.png',
#  '478': 'lefthandlock.png',
#  '479': 'lefthandlock.png',
#  '480': 'lefthandlock.png',
#  '481': 'lefthandlock.png',
#  '482': 'lefthandlock.png',
#  '483': 'lefthandlock.png',
#  '484': 'lefthandlock.png',
#  '485': 'lefthandlock.png',
#  '486': 'lefthandlock.png',
#  '487': 'lefthandlock.png',
#  '634': 'righthandlock.png',
#  '635': 'righthandlock.png',
#  '636': 'righthandlock.png',
#  '637': 'righthandlock.png',
#  '638': 'righthandlock.png',
#  '639': 'righthandlock.png',
#  '640': 'righthandlock.png',
#  '641': 'righthandlock.png',
#  '643': 'righthandlock.png',
#  '644': 'righthandlock.png',
#  '645': 'righthandlock.png',
#  '646': 'righthandlock.png',
#  '647': 'righthandlock.png',
#  '648': 'righthandlock.png',
#  '649': 'righthandlock.png',
#  '650': 'righthandlock.png',
#  '651': 'righthandlock.png',
#  '652': 'righthandlock.png',
#  '653': 'righthandlock.png',
#  '654': 'righthandlock.png',
#  '655': 'righthandlock.png',
#  '656': 'righthandlock.png',
#  '658': 'righthandlock.png',
#  '659': 'righthandlock.png',
#  '660': 'righthandlock.png',
#  '661': 'righthandlock.png',
#  '662': 'righthandlock.png',
#  '663': 'righthandlock.png',
#  '664': 'righthandlock.png',
#  '665': 'righthandlock.png',
#  '666': 'righthandlock.png',
#  '667': 'righthandlock.png',
#  '668': 'righthandlock.png',
#  '669': 'righthandlock.png',
#  '670': 'righthandlock.png',
#  '671': 'righthandlock.png',
#  '672': 'righthandlock.png',
#  '673': 'righthandlock.png',
#  '674': 'righthandlock.png',
#  '675': 'righthandlock.png',
#  '676': 'righthandlock.png',
#  '677': 'righthandlock.png',
#  '678': 'righthandlock.png',
#  '679': 'righthandlock.png',
#  '680': 'righthandlock.png',
#  '681': 'righthandlock.png',
#  '682': 'righthandlock.png',
#  '683': 'righthandlock.png',
#  '684': 'righthandlock.png',
#  '685': 'righthandlock.png',
#  '686': 'righthandlock.png',
#  '687': 'righthandlock.png',
#  '688': 'righthandlock.png',
#  '689': 'righthandlock.png',
#  '690': 'righthandlock.png',
#  '691': 'righthandlock.png',
#  '692': 'righthandlock.png',
#  '693': 'righthandlock.png',
#  '694': 'righthandlock.png',
#  '695': 'righthandlock.png',
#  '696': 'righthandlock.png',
#  '697': 'righthandlock.png',
#  '698': 'righthandlock.png',
#  '699': 'righthandlock.png',
#  '700': 'righthandlock.png',
#  '701': 'righthandlock.png',
#  '702': 'righthandlock.png',
#  '703': 'righthandlock.png',
#  '704': 'righthandlock.png',
#  '705': 'righthandlock.png',
#  '706': 'righthandlock.png',
#  '707': 'righthandlock.png',
#  '708': 'righthandlock.png',
#  '709': 'righthandlock.png',
#  '710': 'righthandlock.png',
#  '711': 'righthandlock.png',
#  '712': 'righthandlock.png',
#  '713': 'righthandlock.png',
#  '714': 'righthandlock.png',
#  '715': 'righthandlock.png',
#  '716': 'righthandlock.png',
#  '717': 'righthandlock.png',
#  '719': 'righthandlock.png',
#  '720': 'righthandlock.png',
#  '721': 'righthandlock.png',
#  '722': 'righthandlock.png',
#  '723': 'righthandlock.png',
#  '724': 'righthandlock.png',
#  '1347': 'bothhandlock.png',
#  '1348': 'bothhandlock.png',
#  '1349': 'bothhandlock.png',
#  '1350': 'bothhandlock.png',
#  '1351': 'bothhandlock.png',
#  '1352': 'bothhandlock.png',
#  '1353': 'bothhandlock.png',
#  '1354': 'bothhandlock.png',
#  '1355': 'bothhandlock.png',
#  '1356': 'bothhandlock.png',
#  '1357': 'bothhandlock.png',
#  '1358': 'bothhandlock.png',
#  '1359': 'bothhandlock.png',
#  '1360': 'bothhandlock.png',
#  '1361': 'bothhandlock.png',
#  '1362': 'bothhandlock.png',
#  '1363': 'bothhandlock.png',
#  '1364': 'bothhandlock.png',
#  '1365': 'bothhandlock.png',
#  '1366': 'bothhandlock.png',
#  '1367': 'bothhandlock.png',
#  '1368': 'bothhandlock.png',
#  '1369': 'bothhandlock.png',
#  '1370': 'bothhandlock.png',
#  '1371': 'bothhandlock.png',
#  '1372': 'bothhandlock.png',
#  '1373': 'bothhandlock.png',
#  '1374': 'bothhandlock.png',
#  '1375': 'bothhandlock.png',
#  '1376': 'bothhandlock.png',
#  '1377': 'bothhandlock.png',
#  '1378': 'bothhandlock.png',
#  '1379': 'bothhandlock.png',
#  '1380': 'bothhandlock.png',
#  '1381': 'bothhandlock.png',
#  '1382': 'bothhandlock.png',
#  '1383': 'bothhandlock.png',
#  '1384': 'bothhandlock.png',
#  '1385': 'bothhandlock.png',
#  '1386': 'bothhandlock.png',
#  '1387': 'bothhandlock.png',
#  '1388': 'bothhandlock.png',
#  '1389': 'bothhandlock.png',
#  '1390': 'bothhandlock.png',
#  '1391': 'bothhandlock.png',
#  '1392': 'bothhandlock.png',
#  '1393': 'bothhandlock.png',
#  '1394': 'bothhandlock.png',
#  '1395': 'bothhandlock.png',
#  '1396': 'bothhandlock.png',
#  '1397': 'bothhandlock.png',
#  '1398': 'bothhandlock.png',
#  '1399': 'bothhandlock.png',
#  '1400': 'bothhandlock.png',
#  '1401': 'bothhandlock.png',
#  '1402': 'bothhandlock.png',
#  '1403': 'bothhandlock.png',
#  '1404': 'bothhandlock.png',
#  '1405': 'bothhandlock.png',
#  '1406': 'bothhandlock.png',
#  '1407': 'bothhandlock.png',
#  '1408': 'bothhandlock.png',
#  '1409': 'bothhandlock.png',
#  '1410': 'bothhandlock.png',
#  '1411': 'bothhandlock.png',
#  '1412': 'bothhandlock.png',
#  '1413': 'bothhandlock.png',
#  '1414': 'bothhandlock.png',
#  '1415': 'bothhandlock.png',
#  '1416': 'bothhandlock.png',
#  '1417': 'bothhandlock.png',
#  '1418': 'bothhandlock.png',
#  '1419': 'bothhandlock.png',
#  '1420': 'bothhandlock.png',
#  '1421': 'bothhandlock.png',
#  '1422': 'bothhandlock.png',
#  '1423': 'bothhandlock.png',
#  '1424': 'bothhandlock.png',
#  '1425': 'bothhandlock.png',
#  '1426': 'bothhandlock.png',
#  '1427': 'bothhandlock.png',
#  '1428': 'bothhandlock.png',
#  '1429': 'bothhandlock.png',
#  '1430': 'bothhandlock.png',
#  '1431': 'bothhandlock.png',
#  '1432': 'bothhandlock.png',
#  '1433': 'bothhandlock.png',
#  '1434': 'bothhandlock.png',
#  '1435': 'bothhandlock.png',
#  '1436': 'bothhandlock.png',
#  '1437': 'bothhandlock.png',
#  '1438': 'bothhandlock.png',
#  '1607': 'lefthandpinch.png',
#  '1608': 'lefthandpinch.png',
#  '1609': 'lefthandpinch.png',
#  '1610': 'lefthandpinch.png',
#  '1611': 'lefthandpinch.png',
#  '1612': 'lefthandpinch.png',
#  '1613': 'lefthandpinch.png',
#  '1614': 'lefthandpinch.png',
#  '1615': 'lefthandpinch.png',
#  '1616': 'lefthandpinch.png',
#  '1617': 'lefthandpinch.png',
#  '1618': 'lefthandpinch.png',
#  '1619': 'lefthandpinch.png',
#  '1620': 'lefthandpinch.png',
#  '1621': 'lefthandpinch.png',
#  '1622': 'lefthandpinch.png',
#  '1623': 'lefthandpinch.png',
#  '1624': 'lefthandpinch.png',
#  '1625': 'lefthandpinch.png',
#  '1626': 'lefthandpinch.png',
#  '1627': 'lefthandpinch.png',
#  '1628': 'lefthandpinch.png',
#  '1629': 'lefthandpinch.png',
#  '1630': 'lefthandpinch.png',
#  '1631': 'lefthandpinch.png',
#  '1632': 'lefthandpinch.png',
#  '1633': 'lefthandpinch.png',
#  '1634': 'lefthandpinch.png',
#  '1635': 'lefthandpinch.png',
#  '1636': 'lefthandpinch.png',
#  '1637': 'lefthandpinch.png',
#  '1638': 'lefthandpinch.png',
#  '1639': 'lefthandpinch.png',
#  '1640': 'lefthandpinch.png',
#  '1641': 'lefthandpinch.png',
#  '1642': 'lefthandpinch.png',
#  '1643': 'lefthandpinch.png',
#  '1644': 'lefthandpinch.png',
#  '1645': 'lefthandpinch.png',
#  '1646': 'lefthandpinch.png',
#  '1647': 'lefthandpinch.png',
#  '1648': 'lefthandpinch.png',
#  '1649': 'lefthandpinch.png',
#  '1650': 'lefthandpinch.png',
#  '1651': 'lefthandpinch.png',
#  '1652': 'lefthandpinch.png',
#  '1653': 'lefthandpinch.png',
#  '1654': 'lefthandpinch.png',
#  '1655': 'lefthandpinch.png',
#  '1656': 'lefthandpinch.png',
#  '1657': 'lefthandpinch.png',
#  '1658': 'lefthandpinch.png',
#  '1659': 'lefthandpinch.png',
#  '1660': 'lefthandpinch.png',
#  '1661': 'lefthandpinch.png',
#  '1662': 'lefthandpinch.png',
#  '1663': 'lefthandpinch.png',
#  '1664': 'lefthandpinch.png',
#  '1665': 'lefthandpinch.png',
#  '1666': 'lefthandpinch.png',
#  '1667': 'lefthandpinch.png',
#  '1668': 'lefthandpinch.png',
#  '1669': 'lefthandpinch.png',
#  '1670': 'lefthandpinch.png',
#  '1671': 'lefthandpinch.png',
#  '1672': 'lefthandpinch.png',
#  '1673': 'lefthandpinch.png',
#  '1674': 'lefthandpinch.png',
#  '1675': 'lefthandpinch.png',
#  '1676': 'lefthandpinch.png',
#  '1677': 'lefthandpinch.png',
#  '1678': 'lefthandpinch.png',
#  '1679': 'lefthandpinch.png',
#  '1680': 'lefthandpinch.png',
#  '1681': 'lefthandpinch.png',
#  '1682': 'lefthandpinch.png',
#  '1683': 'lefthandpinch.png',
#  '1684': 'lefthandpinch.png',
#  '1685': 'lefthandpinch.png',
#  '1686': 'lefthandpinch.png',
#  '1687': 'lefthandpinch.png',
#  '1688': 'lefthandpinch.png',
#  '1689': 'lefthandpinch.png',
#  '1690': 'lefthandpinch.png',
#  '1691': 'lefthandpinch.png',
#  '1692': 'lefthandpinch.png',
#  '1693': 'lefthandpinch.png',
#  '1694': 'lefthandpinch.png',
#  '1695': 'lefthandpinch.png',
#  '1696': 'lefthandpinch.png',
#  '1697': 'lefthandpinch.png',
#  '1698': 'lefthandpinch.png',
#  '2194': 'righthandpinch.png',
#  '2195': 'righthandpinch.png',
#  '2196': 'righthandpinch.png',
#  '2197': 'righthandpinch.png',
#  '2198': 'righthandpinch.png',
#  '2199': 'righthandpinch.png',
#  '2200': 'righthandpinch.png',
#  '2201': 'righthandpinch.png',
#  '2202': 'righthandpinch.png',
#  '2203': 'righthandpinch.png',
#  '2204': 'righthandpinch.png',
#  '2205': 'righthandpinch.png',
#  '2206': 'righthandpinch.png',
#  '2207': 'righthandpinch.png',
#  '2208': 'righthandpinch.png',
#  '2209': 'righthandpinch.png',
#  '2210': 'righthandpinch.png',
#  '2211': 'righthandpinch.png',
#  '2212': 'righthandpinch.png',
#  '2213': 'righthandpinch.png',
#  '2214': 'righthandpinch.png',
#  '2215': 'righthandpinch.png',
#  '2216': 'righthandpinch.png',
#  '2217': 'righthandpinch.png',
#  '2218': 'righthandpinch.png',
#  '2219': 'righthandpinch.png',
#  '2220': 'righthandpinch.png',
#  '2221': 'righthandpinch.png',
#  '2222': 'righthandpinch.png',
#  '2223': 'righthandpinch.png',
#  '2224': 'righthandpinch.png',
#  '2225': 'righthandpinch.png',
#  '2226': 'righthandpinch.png',
#  '2227': 'righthandpinch.png',
#  '2228': 'righthandpinch.png',
#  '2229': 'righthandpinch.png',
#  '2230': 'righthandpinch.png',
#  '2231': 'righthandpinch.png',
#  '2232': 'righthandpinch.png',
#  '2233': 'righthandpinch.png',
#  '2234': 'righthandpinch.png',
#  '2235': 'righthandpinch.png',
#  '2236': 'righthandpinch.png',
#  '2237': 'righthandpinch.png',
#  '2238': 'righthandpinch.png',
#  '2239': 'righthandpinch.png',
#  '2240': 'righthandpinch.png',
#  '2241': 'righthandpinch.png',
#  '2242': 'righthandpinch.png',
#  '2243': 'righthandpinch.png',
#  '2244': 'righthandpinch.png',
#  '2245': 'righthandpinch.png',
#  '2246': 'righthandpinch.png',
#  '2247': 'righthandpinch.png',
#  '2248': 'righthandpinch.png',
#  '2249': 'righthandpinch.png',
#  '2250': 'righthandpinch.png',
#  '2251': 'righthandpinch.png',
#  '2252': 'righthandpinch.png',
#  '2253': 'righthandpinch.png',
#  '2254': 'righthandpinch.png',
#  '2255': 'righthandpinch.png',
#  '2256': 'righthandpinch.png',
#  '2257': 'righthandpinch.png',
#  '2258': 'righthandpinch.png',
#  '2259': 'righthandpinch.png',
#  '2260': 'righthandpinch.png',
#  '2261': 'righthandpinch.png',
#  '2262': 'righthandpinch.png',
#  '2263': 'righthandpinch.png',
#  '2264': 'righthandpinch.png',
#  '2265': 'righthandpinch.png',
#  '2266': 'righthandpinch.png',
#  '2267': 'righthandpinch.png',
#  '2268': 'righthandpinch.png',
#  '2269': 'righthandpinch.png',
#  '2270': 'righthandpinch.png',
#  '2271': 'righthandpinch.png',
#  '2272': 'righthandpinch.png',
#  '2273': 'righthandpinch.png',
#  '2274': 'righthandpinch.png',
#  '2275': 'righthandpinch.png',
#  '2276': 'righthandpinch.png',
#  '2277': 'righthandpinch.png',
#  '2278': 'righthandpinch.png',
#  '2279': 'righthandpinch.png',
#  '2280': 'righthandpinch.png',
#  '2281': 'righthandpinch.png',
#  '2282': 'righthandpinch.png',
#  '2283': 'righthandpinch.png',
#  '2284': 'righthandpinch.png',
#  '2285': 'righthandpinch.png',
#  '2631': 'bothhandpinch.png',
#  '2632': 'bothhandpinch.png',
#  '2633': 'bothhandpinch.png',
#  '2634': 'bothhandpinch.png',
#  '2635': 'bothhandpinch.png',
#  '2636': 'bothhandpinch.png',
#  '2637': 'bothhandpinch.png',
#  '2638': 'bothhandpinch.png',
#  '2639': 'bothhandpinch.png',
#  '2640': 'bothhandpinch.png',
#  '2641': 'bothhandpinch.png',
#  '2642': 'bothhandpinch.png',
#  '2643': 'bothhandpinch.png',
#  '2644': 'bothhandpinch.png',
#  '2645': 'bothhandpinch.png',
#  '2646': 'bothhandpinch.png',
#  '2647': 'bothhandpinch.png',
#  '2648': 'bothhandpinch.png',
#  '2649': 'bothhandpinch.png',
#  '2650': 'bothhandpinch.png',
#  '2651': 'bothhandpinch.png',
#  '2652': 'bothhandpinch.png',
#  '2653': 'bothhandpinch.png',
#  '2654': 'bothhandpinch.png',
#  '2655': 'bothhandpinch.png',
#  '2656': 'bothhandpinch.png',
#  '2657': 'bothhandpinch.png',
#  '2658': 'bothhandpinch.png',
#  '2659': 'bothhandpinch.png',
#  '2660': 'bothhandpinch.png',
#  '2661': 'bothhandpinch.png',
#  '2662': 'bothhandpinch.png',
#  '2663': 'bothhandpinch.png',
#  '2664': 'bothhandpinch.png',
#  '2665': 'bothhandpinch.png',
#  '2666': 'bothhandpinch.png',
#  '2667': 'bothhandpinch.png',
#  '2668': 'bothhandpinch.png',
#  '2669': 'bothhandpinch.png',
#  '2670': 'bothhandpinch.png',
#  '2671': 'bothhandpinch.png',
#  '2672': 'bothhandpinch.png',
#  '2673': 'bothhandpinch.png',
#  '2674': 'bothhandpinch.png',
#  '2675': 'bothhandpinch.png',
#  '2676': 'bothhandpinch.png',
#  '2677': 'bothhandpinch.png',
#  '2678': 'bothhandpinch.png',
#  '2679': 'bothhandpinch.png',
#  '2680': 'bothhandpinch.png',
#  '2681': 'bothhandpinch.png',
#  '2682': 'bothhandpinch.png',
#  '2683': 'bothhandpinch.png',
#  '2684': 'bothhandpinch.png',
#  '2685': 'bothhandpinch.png',
#  '2686': 'bothhandpinch.png',
#  '2687': 'bothhandpinch.png',
#  '2688': 'bothhandpinch.png',
#  '2689': 'bothhandpinch.png',
#  '2690': 'bothhandpinch.png',
#  '2691': 'bothhandpinch.png',
#  '2692': 'bothhandpinch.png',
#  '2693': 'bothhandpinch.png',
#  '2694': 'bothhandpinch.png',
#  '2695': 'bothhandpinch.png',
#  '2696': 'bothhandpinch.png',
#  '2697': 'bothhandpinch.png',
#  '2698': 'bothhandpinch.png',
#  '2699': 'bothhandpinch.png',
#  '2700': 'bothhandpinch.png',
#  '2701': 'bothhandpinch.png',
#  '2702': 'bothhandpinch.png',
#  '2703': 'bothhandpinch.png',
#  '2704': 'bothhandpinch.png',
#  '2705': 'bothhandpinch.png',
#  '2706': 'bothhandpinch.png',
#  '2707': 'bothhandpinch.png',
#  '2708': 'bothhandpinch.png',
#  '2709': 'bothhandpinch.png',
#  '2710': 'bothhandpinch.png',
#  '2711': 'bothhandpinch.png',
#  '2712': 'bothhandpinch.png',
#  '2713': 'bothhandpinch.png',
#  '2714': 'bothhandpinch.png',
#  '2715': 'bothhandpinch.png',
#  '2716': 'bothhandpinch.png',
#  '2717': 'bothhandpinch.png',
#  '2718': 'bothhandpinch.png',
#  '2719': 'bothhandpinch.png',
#  '2720': 'bothhandpinch.png',
#  '2721': 'bothhandpinch.png',
#  '2722': 'bothhandpinch.png',
#  '2781': 'bothhandcover.png',
#  '2782': 'bothhandcover.png',
#  '2783': 'bothhandcover.png',
#  '2784': 'bothhandcover.png',
#  '2785': 'bothhandcover.png',
#  '2786': 'bothhandcover.png',
#  '2787': 'bothhandcover.png',
#  '2788': 'bothhandcover.png',
#  '2789': 'bothhandcover.png',
#  '2790': 'bothhandcover.png',
#  '2791': 'bothhandcover.png',
#  '2792': 'bothhandcover.png',
#  '2793': 'bothhandcover.png',
#  '2794': 'bothhandcover.png',
#  '2795': 'bothhandcover.png',
#  '2797': 'bothhandcover.png',
#  '2798': 'bothhandcover.png',
#  '2799': 'bothhandcover.png',
#  '2800': 'bothhandcover.png',
#  '2801': 'bothhandcover.png',
#  '2802': 'bothhandcover.png',
#  '2803': 'bothhandcover.png',
#  '2805': 'bothhandcover.png',
#  '2806': 'bothhandcover.png',
#  '2807': 'bothhandcover.png',
#  '2808': 'bothhandcover.png',
#  '2809': 'bothhandcover.png',
#  '2810': 'bothhandcover.png',
#  '2811': 'bothhandcover.png',
#  '2812': 'bothhandcover.png',
#  '2813': 'bothhandcover.png',
#  '2814': 'bothhandcover.png',
#  '2815': 'bothhandcover.png',
#  '2816': 'bothhandcover.png',
#  '2817': 'bothhandcover.png',
#  '2818': 'bothhandcover.png',
#  '2819': 'bothhandcover.png',
#  '2820': 'bothhandcover.png',
#  '2821': 'bothhandcover.png',
#  '2822': 'bothhandcover.png',
#  '2823': 'bothhandcover.png',
#  '2824': 'bothhandcover.png',
#  '2825': 'bothhandcover.png',
#  '2826': 'bothhandcover.png',
#  '2827': 'bothhandcover.png',
#  '2828': 'bothhandcover.png',
#  '2829': 'bothhandcover.png',
#  '2830': 'bothhandcover.png',
#  '2831': 'bothhandcover.png',
#  '2832': 'bothhandcover.png',
#  '2833': 'bothhandcover.png',
#  '2834': 'bothhandcover.png',
#  '2835': 'bothhandcover.png',
#  '2836': 'bothhandcover.png',
#  '2837': 'bothhandcover.png',
#  '2838': 'bothhandcover.png',
#  '2839': 'bothhandcover.png',
#  '2840': 'bothhandcover.png',
#  '2841': 'bothhandcover.png',
#  '2842': 'bothhandcover.png',
#  '2843': 'bothhandcover.png',
#  '2844': 'bothhandcover.png',
#  '2845': 'bothhandcover.png',
#  '2846': 'bothhandcover.png',
#  '2847': 'bothhandcover.png',
#  '2848': 'bothhandcover.png',
#  '2849': 'bothhandcover.png',
#  '2850': 'bothhandcover.png',
#  '2851': 'bothhandcover.png',
#  '2852': 'bothhandcover.png',
#  '2853': 'bothhandcover.png',
#  '2854': 'bothhandcover.png',
#  '2855': 'bothhandcover.png',
#  '2856': 'bothhandcover.png',
#  '2857': 'bothhandcover.png',
#  '2858': 'bothhandcover.png',
#  '2859': 'bothhandcover.png',
#  '2860': 'bothhandcover.png',
#  '2861': 'bothhandcover.png',
#  '2862': 'bothhandcover.png',
#  '2863': 'bothhandcover.png',
#  '2864': 'bothhandcover.png',
#  '2865': 'bothhandcover.png',
#  '2866': 'bothhandcover.png',
#  '2867': 'bothhandcover.png',
#  '2868': 'bothhandcover.png',
#  '2869': 'bothhandcover.png',
#  '2870': 'bothhandcover.png',
#  '2871': 'bothhandcover.png',
#  '2872': 'bothhandcover.png',
#  '2873': 'bothhandcover.png',
#  '3381': 'lefthandfist.png',
#  '3382': 'lefthandfist.png',
#  '3383': 'lefthandfist.png',
#  '3384': 'lefthandfist.png',
#  '3385': 'lefthandfist.png',
#  '3386': 'lefthandfist.png',
#  '3387': 'lefthandfist.png',
#  '3388': 'lefthandfist.png',
#  '3389': 'lefthandfist.png',
#  '3390': 'lefthandfist.png',
#  '3391': 'lefthandfist.png',
#  '3392': 'lefthandfist.png',
#  '3393': 'lefthandfist.png',
#  '3394': 'lefthandfist.png',
#  '3395': 'lefthandfist.png',
#  '3396': 'lefthandfist.png',
#  '3397': 'lefthandfist.png',
#  '3398': 'lefthandfist.png',
#  '3399': 'lefthandfist.png',
#  '3400': 'lefthandfist.png',
#  '3401': 'lefthandfist.png',
#  '3402': 'lefthandfist.png',
#  '3403': 'lefthandfist.png',
#  '3404': 'lefthandfist.png',
#  '3405': 'lefthandfist.png',
#  '3406': 'lefthandfist.png',
#  '3407': 'lefthandfist.png',
#  '3408': 'lefthandfist.png',
#  '3409': 'lefthandfist.png',
#  '3410': 'lefthandfist.png',
#  '3411': 'lefthandfist.png',
#  '3412': 'lefthandfist.png',
#  '3413': 'lefthandfist.png',
#  '3414': 'lefthandfist.png',
#  '3415': 'lefthandfist.png',
#  '3416': 'lefthandfist.png',
#  '3417': 'lefthandfist.png',
#  '3418': 'lefthandfist.png',
#  '3419': 'lefthandfist.png',
#  '3420': 'lefthandfist.png',
#  '3421': 'lefthandfist.png',
#  '3422': 'lefthandfist.png',
#  '3423': 'lefthandfist.png',
#  '3424': 'lefthandfist.png',
#  '3425': 'lefthandfist.png',
#  '3426': 'lefthandfist.png',
#  '3427': 'lefthandfist.png',
#  '3428': 'lefthandfist.png',
#  '3429': 'lefthandfist.png',
#  '3430': 'lefthandfist.png',
#  '3431': 'lefthandfist.png',
#  '3432': 'lefthandfist.png',
#  '3433': 'lefthandfist.png',
#  '3434': 'lefthandfist.png',
#  '3435': 'lefthandfist.png',
#  '3436': 'lefthandfist.png',
#  '3437': 'lefthandfist.png',
#  '3438': 'lefthandfist.png',
#  '3439': 'lefthandfist.png',
#  '3440': 'lefthandfist.png',
#  '3441': 'lefthandfist.png',
#  '3442': 'lefthandfist.png',
#  '3443': 'lefthandfist.png',
#  '3444': 'lefthandfist.png',
#  '3445': 'lefthandfist.png',
#  '3446': 'lefthandfist.png',
#  '3447': 'lefthandfist.png',
#  '3448': 'lefthandfist.png',
#  '3449': 'lefthandfist.png',
#  '3450': 'lefthandfist.png',
#  '3451': 'lefthandfist.png',
#  '3452': 'lefthandfist.png',
#  '3453': 'lefthandfist.png',
#  '3454': 'lefthandfist.png',
#  '3455': 'lefthandfist.png',
#  '3456': 'lefthandfist.png',
#  '3457': 'lefthandfist.png',
#  '3458': 'lefthandfist.png',
#  '3459': 'lefthandfist.png',
#  '3460': 'lefthandfist.png',
#  '3461': 'lefthandfist.png',
#  '3462': 'lefthandfist.png',
#  '3463': 'lefthandfist.png',
#  '3464': 'lefthandfist.png',
#  '3465': 'lefthandfist.png',
#  '3466': 'lefthandfist.png',
#  '3467': 'lefthandfist.png',
#  '3468': 'lefthandfist.png',
#  '3469': 'lefthandfist.png',
#  '3470': 'lefthandfist.png',
#  '3471': 'lefthandfist.png',
#  '3736': 'righthandfist.png',
#  '3737': 'righthandfist.png',
#  '3738': 'righthandfist.png',
#  '3739': 'righthandfist.png',
#  '3740': 'righthandfist.png',
#  '3741': 'righthandfist.png',
#  '3742': 'righthandfist.png',
#  '3743': 'righthandfist.png',
#  '3744': 'righthandfist.png',
#  '3745': 'righthandfist.png',
#  '3746': 'righthandfist.png',
#  '3747': 'righthandfist.png',
#  '3748': 'righthandfist.png',
#  '3749': 'righthandfist.png',
#  '3750': 'righthandfist.png',
#  '3751': 'righthandfist.png',
#  '3752': 'righthandfist.png',
#  '3753': 'righthandfist.png',
#  '3754': 'righthandfist.png',
#  '3755': 'righthandfist.png',
#  '3756': 'righthandfist.png',
#  '3757': 'righthandfist.png',
#  '3758': 'righthandfist.png',
#  '3759': 'righthandfist.png',
#  '3760': 'righthandfist.png',
#  '3761': 'righthandfist.png',
#  '3762': 'righthandfist.png',
#  '3763': 'righthandfist.png',
#  '3764': 'righthandfist.png',
#  '3765': 'righthandfist.png',
#  '3766': 'righthandfist.png',
#  '3767': 'righthandfist.png',
#  '3768': 'righthandfist.png',
#  '3769': 'righthandfist.png',
#  '3770': 'righthandfist.png',
#  '3771': 'righthandfist.png',
#  '3772': 'righthandfist.png',
#  '3774': 'righthandfist.png',
#  '3775': 'righthandfist.png',
#  '3776': 'righthandfist.png',
#  '3777': 'righthandfist.png',
#  '3778': 'righthandfist.png',
#  '3779': 'righthandfist.png',
#  '3780': 'righthandfist.png',
#  '3781': 'righthandfist.png',
#  '3782': 'righthandfist.png',
#  '3783': 'righthandfist.png',
#  '3784': 'righthandfist.png',
#  '3785': 'righthandfist.png',
#  '3786': 'righthandfist.png',
#  '3787': 'righthandfist.png',
#  '3788': 'righthandfist.png',
#  '3789': 'righthandfist.png',
#  '3790': 'righthandfist.png',
#  '3791': 'righthandfist.png',
#  '3792': 'righthandfist.png',
#  '3793': 'righthandfist.png',
#  '3794': 'righthandfist.png',
#  '3795': 'righthandfist.png',
#  '3796': 'righthandfist.png',
#  '3797': 'righthandfist.png',
#  '3798': 'righthandfist.png',
#  '3799': 'righthandfist.png',
#  '3800': 'righthandfist.png',
#  '3801': 'righthandfist.png',
#  '3802': 'righthandfist.png',
#  '3803': 'righthandfist.png',
#  '3804': 'righthandfist.png',
#  '3805': 'righthandfist.png',
#  '3806': 'righthandfist.png',
#  '3807': 'righthandfist.png',
#  '3808': 'righthandfist.png',
#  '3809': 'righthandfist.png',
#  '3810': 'righthandfist.png',
#  '3811': 'righthandfist.png',
#  '3812': 'righthandfist.png',
#  '3813': 'righthandfist.png',
#  '3814': 'righthandfist.png',
#  '3815': 'righthandfist.png',
#  '3816': 'righthandfist.png',
#  '3817': 'righthandfist.png',
#  '3818': 'righthandfist.png',
#  '3819': 'righthandfist.png',
#  '3820': 'righthandfist.png',
#  '3821': 'righthandfist.png',
#  '3822': 'righthandfist.png',
#  '3823': 'righthandfist.png',
#  '3824': 'righthandfist.png',
#  '3825': 'righthandfist.png',
#  '3826': 'righthandfist.png',
#  '3827': 'righthandfist.png',
#  '4417': 'bothhandfist.png',
#  '4418': 'bothhandfist.png',
#  '4419': 'bothhandfist.png',
#  '4420': 'bothhandfist.png',
#  '4421': 'bothhandfist.png',
#  '4422': 'bothhandfist.png',
#  '4423': 'bothhandfist.png',
#  '4424': 'bothhandfist.png',
#  '4425': 'bothhandfist.png',
#  '4426': 'bothhandfist.png',
#  '4427': 'bothhandfist.png',
#  '4428': 'bothhandfist.png',
#  '4429': 'bothhandfist.png',
#  '4430': 'bothhandfist.png',
#  '4431': 'bothhandfist.png',
#  '4432': 'bothhandfist.png',
#  '4433': 'bothhandfist.png',
#  '4434': 'bothhandfist.png',
#  '4435': 'bothhandfist.png',
#  '4436': 'bothhandfist.png',
#  '4437': 'bothhandfist.png',
#  '4438': 'bothhandfist.png',
#  '4439': 'bothhandfist.png',
#  '4440': 'bothhandfist.png',
#  '4441': 'bothhandfist.png',
#  '4442': 'bothhandfist.png',
#  '4443': 'bothhandfist.png',
#  '4444': 'bothhandfist.png',
#  '4445': 'bothhandfist.png',
#  '4446': 'bothhandfist.png',
#  '4447': 'bothhandfist.png',
#  '4448': 'bothhandfist.png',
#  '4449': 'bothhandfist.png',
#  '4450': 'bothhandfist.png',
#  '4451': 'bothhandfist.png',
#  '4452': 'bothhandfist.png',
#  '4453': 'bothhandfist.png',
#  '4454': 'bothhandfist.png',
#  '4455': 'bothhandfist.png',
#  '4456': 'bothhandfist.png',
#  '4457': 'bothhandfist.png',
#  '4458': 'bothhandfist.png',
#  '4459': 'bothhandfist.png',
#  '4460': 'bothhandfist.png',
#  '4461': 'bothhandfist.png',
#  '4462': 'bothhandfist.png',
#  '4463': 'bothhandfist.png',
#  '4464': 'bothhandfist.png',
#  '4465': 'bothhandfist.png',
#  '4466': 'bothhandfist.png',
#  '4467': 'bothhandfist.png',
#  '4468': 'bothhandfist.png',
#  '4469': 'bothhandfist.png',
#  '4470': 'bothhandfist.png',
#  '4471': 'bothhandfist.png',
#  '4472': 'bothhandfist.png',
#  '4473': 'bothhandfist.png',
#  '4474': 'bothhandfist.png',
#  '4475': 'bothhandfist.png',
#  '4476': 'bothhandfist.png',
#  '4477': 'bothhandfist.png',
#  '4478': 'bothhandfist.png',
#  '4479': 'bothhandfist.png',
#  '4480': 'bothhandfist.png',
#  '4481': 'bothhandfist.png',
#  '4482': 'bothhandfist.png',
#  '4483': 'bothhandfist.png',
#  '4484': 'bothhandfist.png',
#  '4485': 'bothhandfist.png',
#  '4486': 'bothhandfist.png',
#  '4487': 'bothhandfist.png',
#  '4488': 'bothhandfist.png',
#  '4489': 'bothhandfist.png',
#  '4490': 'bothhandfist.png',
#  '4491': 'bothhandfist.png',
#  '4492': 'bothhandfist.png',
#  '4493': 'bothhandfist.png',
#  '4494': 'bothhandfist.png',
#  '4495': 'bothhandfist.png',
#  '4496': 'bothhandfist.png',
#  '4497': 'bothhandfist.png',
#  '4498': 'bothhandfist.png',
#  '4499': 'bothhandfist.png',
#  '4500': 'bothhandfist.png',
#  '4501': 'bothhandfist.png',
#  '4502': 'bothhandfist.png',
#  '4503': 'bothhandfist.png',
#  '4504': 'bothhandfist.png',
#  '4505': 'bothhandfist.png',
#  '4506': 'bothhandfist.png',
#  '4507': 'bothhandfist.png',
#  '4619': 'upperlefthandlock.png',
#  '4620': 'upperlefthandlock.png',
#  '4621': 'upperlefthandlock.png',
#  '4622': 'upperlefthandlock.png',
#  '4623': 'upperlefthandlock.png',
#  '4624': 'upperlefthandlock.png',
#  '4625': 'upperlefthandlock.png',
#  '4626': 'upperlefthandlock.png',
#  '4628': 'upperlefthandlock.png',
#  '4629': 'upperlefthandlock.png',
#  '4630': 'upperlefthandlock.png',
#  '4631': 'upperlefthandlock.png',
#  '4632': 'upperlefthandlock.png',
#  '4633': 'upperlefthandlock.png',
#  '4634': 'upperlefthandlock.png',
#  '4635': 'upperlefthandlock.png',
#  '4636': 'upperlefthandlock.png',
#  '4637': 'upperlefthandlock.png',
#  '4638': 'upperlefthandlock.png',
#  '4639': 'upperlefthandlock.png',
#  '4640': 'upperlefthandlock.png',
#  '4641': 'upperlefthandlock.png',
#  '4642': 'upperlefthandlock.png',
#  '4643': 'upperlefthandlock.png',
#  '4644': 'upperlefthandlock.png',
#  '4645': 'upperlefthandlock.png',
#  '4646': 'upperlefthandlock.png',
#  '4647': 'upperlefthandlock.png',
#  '4648': 'upperlefthandlock.png',
#  '4649': 'upperlefthandlock.png',
#  '4650': 'upperlefthandlock.png',
#  '4651': 'upperlefthandlock.png',
#  '4652': 'upperlefthandlock.png',
#  '4653': 'upperlefthandlock.png',
#  '4654': 'upperlefthandlock.png',
#  '4655': 'upperlefthandlock.png',
#  '4656': 'upperlefthandlock.png',
#  '4657': 'upperlefthandlock.png',
#  '4658': 'upperlefthandlock.png',
#  '4659': 'upperlefthandlock.png',
#  '4660': 'upperlefthandlock.png',
#  '4661': 'upperlefthandlock.png',
#  '4662': 'upperlefthandlock.png',
#  '4663': 'upperlefthandlock.png',
#  '4664': 'upperlefthandlock.png',
#  '4665': 'upperlefthandlock.png',
#  '4666': 'upperlefthandlock.png',
#  '4667': 'upperlefthandlock.png',
#  '4668': 'upperlefthandlock.png',
#  '4669': 'upperlefthandlock.png',
#  '4670': 'upperlefthandlock.png',
#  '4671': 'upperlefthandlock.png',
#  '4672': 'upperlefthandlock.png',
#  '4673': 'upperlefthandlock.png',
#  '4674': 'upperlefthandlock.png',
#  '4675': 'upperlefthandlock.png',
#  '4676': 'upperlefthandlock.png',
#  '4677': 'upperlefthandlock.png',
#  '4678': 'upperlefthandlock.png',
#  '4679': 'upperlefthandlock.png',
#  '4680': 'upperlefthandlock.png',
#  '4681': 'upperlefthandlock.png',
#  '4682': 'upperlefthandlock.png',
#  '4683': 'upperlefthandlock.png',
#  '4684': 'upperlefthandlock.png',
#  '4685': 'upperlefthandlock.png',
#  '4686': 'upperlefthandlock.png',
#  '4687': 'upperlefthandlock.png',
#  '4688': 'upperlefthandlock.png',
#  '4689': 'upperlefthandlock.png',
#  '4690': 'upperlefthandlock.png',
#  '4691': 'upperlefthandlock.png',
#  '4692': 'upperlefthandlock.png',
#  '4693': 'upperlefthandlock.png',
#  '4694': 'upperlefthandlock.png',
#  '4695': 'upperlefthandlock.png',
#  '4696': 'upperlefthandlock.png',
#  '4697': 'upperlefthandlock.png',
#  '4698': 'upperlefthandlock.png',
#  '4699': 'upperlefthandlock.png',
#  '4700': 'upperlefthandlock.png',
#  '4701': 'upperlefthandlock.png',
#  '4702': 'upperlefthandlock.png',
#  '4703': 'upperlefthandlock.png',
#  '4704': 'upperlefthandlock.png',
#  '4705': 'upperlefthandlock.png',
#  '4706': 'upperlefthandlock.png',
#  '4707': 'upperlefthandlock.png',
#  '4708': 'upperlefthandlock.png',
#  ...}

# %%
list(set(a))
# Out:
# ['17518',
#  '10230',
#  '16971',
#  '10188',
#  '9138',
#  '9123',
#  '9117',
#  '15423',
#  '15358',
#  '10693',
#  '2202',
#  '1419',
#  '14984',
#  '11712',
#  '428',
#  '11011',
#  '13385',
#  '3807',
#  '8427',
#  '14999',
#  '1643',
#  '13359',
#  '3811',
#  '11075',
#  '16216',
#  '10165',
#  '8385',
#  '2644',
#  '16817',
#  '5619',
#  '5349',
#  '8404',
#  '453',
#  '461',
#  '3751',
#  '6237',
#  '5587',
#  '12848',
#  '7674',
#  '7634',
#  '11066',
#  '3468',
#  '17763',
#  '16852',
#  '3790',
#  '4702',
#  '17544',
#  '430',
#  '698',
#  '15529',
#  '5297',
#  '654',
#  '674',
#  '6213',
#  '4437',
#  '7624',
#  '3799',
#  '4486',
#  '13358',
#  '5344',
#  '15520',
#  '14973',
#  '4433',
#  '12296',
#  '4663',
#  '9882',
#  '13386',
#  '1362',
#  '6171',
#  '12237',
#  '12866',
#  '17755',
#  '11061',
#  '2701',
#  '1645',
#  '9134',
#  '8807',
#  '9888',
#  '1686',
#  '15946',
#  '7639',
#  '15392',
#  '17575',
#  '7630',
#  '16196',
#  '16281',
#  '12268',
#  '450',
#  '8888',
#  '2641',
#  '7678',
#  '9884',
#  '12892',
#  '17567',
#  '8380',
#  '7177',
#  '6218',
#  '11419',
#  '16240',
#  '7001',
#  '10145',
#  '6203',
#  '17545',
#  '17808',
#  '8348',
#  '16193',
#  '7645',
#  '11683',
#  '4493',
#  '663',
#  '16830',
#  '16218',
#  '6957',
#  '7132',
#  '8234',
#  '12932',
#  '13880',
#  '454',
#  '1683',
#  '10210',
#  '14336',
#  '12262',
#  '10205',
#  '17003',
#  '15569',
#  '17574',
#  '2250',
#  '14940',
#  '4471',
#  '8383',
#  '11047',
#  '719',
#  '8191',
#  '16810',
#  '12252',
#  '2651',
#  '8418',
#  '13858',
#  '447',
#  '17769',
#  '13895',
#  '17025',
#  '15898',
#  '11080',
#  '17765',
#  '1674',
#  '8369',
#  '4488',
#  '17782',
#  '12219',
#  '15514',
#  '13465',
#  '16818',
#  '7167',
#  '17549',
#  '1660',
#  '15568',
#  '16800',
#  '2666',
#  '2257',
#  '1422',
#  '10196',
#  '16990',
#  '15010',
#  '5606',
#  '14939',
#  '5586',
#  '17762',
#  '1384',
#  '10680',
#  '2830',
#  '457',
#  '3767',
#  '11055',
#  '2252',
#  '676',
#  '6206',
#  '15867',
#  '7627',
#  '15441',
#  '8419',
#  '12295',
#  '2822',
#  '15917',
#  '5569',
#  '13859',
#  '9127',
#  '8360',
#  '8841',
#  '10709',
#  '10209',
#  '2864',
#  '12905',
#  '2841',
#  '5309',
#  '6228',
#  '7623',
#  '9842',
#  '14326',
#  '417',
#  '14371',
#  '15932',
#  '15936',
#  '12263',
#  '15580',
#  '1356',
#  '7598',
#  '5361',
#  '12939',
#  '7653',
#  '9100',
#  '2244',
#  '1675',
#  '12270',
#  '7649',
#  '3827',
#  '2696',
#  '412',
#  '11490',
#  '15571',
#  '15939',
#  '16796',
#  '16991',
#  '446',
#  '17576',
#  '707',
#  '1399',
#  '2201',
#  '17768',
#  '15523',
#  '15439',
#  '6998',
#  '6233',
#  '2655',
#  '16980',
#  '9166',
#  '10182',
#  '4467',
#  '3736',
#  '2667',
#  '13904',
#  '2263',
#  '7629',
#  '4648',
#  '12875',
#  '4672',
#  '9132',
#  '9908',
#  '4651',
#  '15934',
#  '2643',
#  '8232',
#  '16203',
#  '2665',
#  '13478',
#  '2648',
#  '13536',
#  '9894',
#  '4464',
#  '1640',
#  '7679',
#  '13339',
#  '14385',
#  '15414',
#  '15927',
#  '13894',
#  '7021',
#  '2228',
#  '13323',
#  '16274',
#  '2831',
#  '1388',
#  '16233',
#  '17571',
#  '15907',
#  '7152',
#  '7039',
#  '12860',
#  '15588',
#  '14981',
#  '16868',
#  '17014',
#  '7013',
#  '418',
#  '7009',
#  '10228',
#  '15006',
#  '16197',
#  '11501',
#  '1428',
#  '8827',
#  '7183',
#  '11042',
#  '15537',
#  '12852',
#  '11689',
#  '11093',
#  '15563',
#  '475',
#  '17748',
#  '1653',
#  '9905',
#  '13878',
#  '2702',
#  '9173',
#  '8199',
#  '5556',
#  '17020',
#  '11473',
#  '13510',
#  '10169',
#  '8846',
#  '9126',
#  '14980',
#  '16844',
#  '10214',
#  '7037',
#  '2797',
#  '2788',
#  '4500',
#  '12928',
#  '16829',
#  '4424',
#  '5366',
#  '2716',
#  '7029',
#  '9851',
#  '11646',
#  '10192',
#  '5627',
#  '14337',
#  '7111',
#  '1406',
#  '5584',
#  '8223',
#  '13368',
#  '16239',
#  '16963',
#  '7164',
#  '4622',
#  '10723',
#  '2690',
#  '16949',
#  '13388',
#  '17595',
#  '7173',
#  '427',
#  '5286',
#  '9102',
#  '15394',
#  '3761',
#  '2671',
#  '4469',
#  '2783',
#  '9180',
#  '3405',
#  '8352',
#  '9152',
#  '10730',
#  '5351',
#  '6215',
#  '6246',
#  '9890',
#  '17777',
#  '10704',
#  '3403',
#  '17004',
#  '10708',
#  '15438',
#  '13324',
#  '14947',
#  '15878',
#  '6243',
#  '3419',
#  '17826',
#  '5634',
#  '15528',
#  '9883',
#  '5599',
#  '12238',
#  '11468',
#  '15376',
#  '2795',
#  '1676',
#  '9895',
#  '6200',
#  '7024',
#  '17592',
#  '9178',
#  '15521',
#  '11663',
#  '11509',
#  '8409',
#  '16280',
#  '16961',
#  '4661',
#  '8401',
#  '4478',
#  '15527',
#  '13371',
#  '7035',
#  '11020',
#  '15894',
#  '14321',
#  '11665',
#  '474',
#  '2662',
#  '15600',
#  '4685',
#  '11068',
#  '9870',
#  '463',
#  '3785',
#  '421',
#  '14977',
#  '17830',
#  '5353',
#  '17580',
#  '1654',
#  '6222',
#  '6224',
#  '17508',
#  '6229',
#  '13484',
#  '8832',
#  '16954',
#  '16259',
#  '9881',
#  '3420',
#  '459',
#  '14372',
#  '1688',
#  '11496',
#  '1359',
#  '1412',
#  '1656',
#  '11458',
#  '5602',
#  '1691',
#  '7659',
#  '11021',
#  '13833',
#  '15887',
#  '4660',
#  '17519',
#  '435',
#  '5368',
#  '11418',
#  '11455',
#  '15417',
#  '3802',
#  '17835',
#  '13471',
#  '6966',
#  '4448',
#  '11439',
#  '7118',
#  '16981',
#  '3452',
#  '11025',
#  '11673',
#  '8823',
#  '9129',
#  '2664',
#  '14339',
#  '8366',
#  '16792',
#  '12284',
#  '2220',
#  '643',
#  '5333',
#  '8393',
#  '11695',
#  '1409',
#  '10752',
#  '9912',
#  '2236',
#  '8170',
#  '3789',
#  '11054',
#  '17816',
#  '17562',
#  '9119',
#  '8210',
#  '8858',
#  '11072',
#  '2827',
#  '8428',
#  '14989',
#  '11711',
#  '16801',
#  '2632',
#  '16959',
#  '9896',
#  '17591',
#  '11681',
#  '12246',
#  '7122',
#  '17784',
#  '7140',
#  '3443',
#  '13545',
#  '7150',
#  '8166',
#  '13836',
#  '7120',
#  '13848',
#  '10699',
#  '7042',
#  '8207',
#  '13500',
#  '4642',
#  '16793',
#  '8855',
#  '11644',
#  '1646',
#  '12927',
#  '16857',
#  '4428',
#  '4625',
#  '8883',
#  '11661',
#  '14955',
#  '11691',
#  '5326',
#  '3755',
#  '8365',
#  '15923',
#  '11064',
#  '15935',
#  '15027',
#  '14961',
#  '13487',
#  '3464',
#  '13883',
#  '8812',
#  '13380',
#  '14349',
#  '16946',
#  '8844',
#  '8826',
#  '8358',
#  '11643',
#  '10754',
#  '15393',
#  '2782',
#  '14948',
#  '17797',
#  '10149',
#  '12267',
#  '2861',
#  '9838',
#  '13548',
#  '8851',
#  '17821',
#  '7605',
#  '4697',
#  '13321',
#  '16854',
#  '5577',
#  '7110',
#  '2686',
#  '2274',
#  '2233',
#  '15553',
#  '11034',
#  '7660',
#  '712',
#  '5323',
#  '5342',
#  '7682',
#  '10716',
#  '9897',
#  '8434',
#  '2235',
#  '13912',
#  '14313',
#  '2836',
#  '5585',
#  '1418',
#  '13516',
#  '3739',
#  '2793',
#  '3794',
#  '1402',
#  '11478',
#  '11507',
#  '13505',
#  '16211',
#  '4671',
#  '17827',
#  '17029',
#  '10183',
#  '17522',
#  '14347',
#  '8407',
#  '3806',
#  '5616',
#  '5645',
#  '9836',
#  '10190',
#  '11010',
#  '7004',
#  '12220',
#  '13889',
#  '17772',
#  '17805',
#  '15885',
#  '5579',
#  '15868',
#  '9137',
#  '13530',
#  '2825',
#  '14358',
#  '9919',
#  '9107',
#  '12882',
#  '2638',
#  '8186',
#  '15597',
#  '2266',
#  '5571',
#  '15359',
#  '9893',
#  '12872',
#  '9112',
#  '13885',
#  '7117',
#  '15370',
#  '15925',
#  '14323',
#  '1663',
#  '14378',
#  '4707',
#  '2722',
#  '11693',
#  '5620',
#  '15526',
#  '2204',
#  '8420',
#  '8829',
#  '9910',
#  '2676',
#  '17800',
#  '469',
#  '7684',
#  '11671',
#  '7637',
#  '8177',
#  '6161',
#  '16248',
#  '11094',
#  '2672',
#  '2784',
#  '7608',
#  '2703',
#  '2823',
#  '7614',
#  '11674',
#  '6172',
#  '15582',
#  '7626',
#  '6225',
#  '2230',
#  '9841',
#  '12254',
#  '17770',
#  '13496',
#  '16209',
#  '2239',
#  '5298',
#  '16848',
#  '1361',
#  '639',
#  '10734',
#  '15914',
#  '13543',
#  '1608',
#  '13363',
#  '17776',
#  '6247',
#  '11699',
#  '6965',
#  '7144',
#  '9139',
#  '8389',
#  '17566',
#  '16221',
#  '2269',
#  '11449',
#  '12227',
#  '10218',
#  '1657',
#  '6223',
#  '11457',
#  '13504',
#  '4629',
#  '9156',
#  '408',
#  '15380',
#  '6967',
#  '4434',
#  '12849',
#  '8398',
#  '5592',
#  '8839',
#  '10155',
#  '16837',
#  '7032',
#  '5566',
#  '5613',
#  '8173',
#  '15926',
#  '11669',
#  '9159',
#  '5288',
#  '7133',
#  '17751',
#  '7675',
#  '7657',
#  '16214',
#  '15384',
#  '15016',
#  '13908',
#  '14335',
#  '15886',
#  '12245',
#  '2816',
#  '11672',
#  '11056',
#  '708',
#  '16252',
#  '4458',
#  '17790',
#  '3450',
#  '4668',
#  '2691',
#  '3769',
#  '7115',
#  '4623',
#  '1655',
#  '10725',
#  '2215',
#  '8165',
#  '5305',
#  '12299',
#  '15403',
#  '11435',
#  '16951',
#  '10742',
#  '3797',
#  '3453',
#  '8240',
#  '12273',
#  '682',
#  '9103',
#  '2837',
#  '3445',
#  '10175',
#  '4506',
#  '684',
#  '4442',
#  '12231',
#  '15434',
#  '9091',
#  '13389',
#  '6969',
#  '16974',
#  '2810',
#  '3743',
#  '3779',
#  '6174',
#  '2853',
#  '662',
#  '3816',
#  '466',
#  '6166',
#  '11053',
#  '2787',
#  '17002',
#  '5639',
#  '9902',
#  '7154',
#  '8424',
#  '13333',
#  '15374',
#  '2813',
#  '17597',
#  '2811',
#  '2852',
#  '9145',
#  '17510',
#  '9901',
#  '16219',
#  '13861',
#  '9847',
#  '2710',
#  '5560',
#  '12930',
#  '17787',
#  '14964',
#  '14985',
#  '3742',
#  '16215',
#  '1432',
#  '15598',
#  '11713',
#  '1619',
#  '7680',
#  '16254',
#  '2845',
#  '1673',
#  '3431',
#  '6990',
#  '9865',
#  '10753',
#  '10231',
#  '2675',
#  '3444',
#  '9163',
#  '5312',
#  '15900',
#  '9118',
#  '5327',
#  '4658',
#  '8208',
#  '15560',
#  '17560',
#  '13535',
#  '4700',
#  '14941',
#  '10692',
#  '8886',
#  '8379',
#  '11436',
#  '12253',
#  '2246',
#  '4452',
#  '4502',
#  '13343',
#  '4432',
#  '7618',
#  '9093',
#  '7182',
#  '5581',
#  '11032',
#  '17824',
#  '5561',
#  '5646',
#  '13893',
#  '15921',
#  '1349',
#  '9104',
#  '13872',
#  '1649',
#  '11026',
#  '16845',
#  '4692',
#  '693',
#  '2225',
#  '2646',
#  '9874',
#  '13538',
#  '6951',
#  '16839',
#  '16999',
#  '10153',
#  '15908',
#  '10670',
#  '11073',
#  '7033',
#  '8824',
#  '15385',
#  '4631',
#  '8230',
#  '8881',
#  '6975',
#  '4634',
#  '6984',
#  '13823',
#  '11099',
#  '16955',
#  '7655',
#  '16802',
#  '695',
#  '7103',
#  '2798',
#  '15422',
#  '7018',
#  '15564',
#  '6226',
#  '1636',
#  '11707',
#  '3772',
#  '11708',
#  '12211',
#  '7038',
#  '9925',
#  '10714',
#  '16969',
#  '6979',
#  '4675',
#  '5306',
#  '5618',
#  '11702',
#  '1637',
#  '12287',
#  '17837',
#  '7633',
#  '1407',
#  '3741',
#  '8243',
#  '14350',
#  '4666',
#  '7631',
#  '8203',
#  '9843',
#  '14331',
#  '14333',
#  '14391',
#  '15557',
#  '5367',
#  '15013',
#  '462',
#  '15605',
#  '8384',
#  '6955',
#  '4470',
#  '4444',
#  '15592',
#  '15595',
#  '5595',
#  '2636',
#  '6959',
#  '16784',
#  '7169',
#  '16825',
#  '3437',
#  '17027',
#  '17523',
#  '5641',
#  '8431',
#  '15021',
#  '11018',
#  '15888',
#  '2238',
#  '437',
#  '12897',
#  '15591',
#  '1353',
#  '16815',
#  '5568',
#  '10222',
#  '8251',
#  '8813',
#  '13911',
#  '1666',
#  '8242',
#  '14954',
#  '8411',
#  '12911',
#  '17752',
#  '11440',
#  '6235',
#  '2803',
#  '2222',
#  '5583',
#  '8204',
#  '9157',
#  '7107',
#  '15018',
#  '7600',
#  '6184',
#  '5301',
#  '11050',
#  '6986',
#  '15440',
#  '17783',
#  '1669',
#  '17552',
#  '9886',
#  '706',
#  '2275',
#  '17011',
#  '13842',
#  '13847',
#  '12241',
#  '1634',
#  '15012',
#  '10170',
#  '15876',
#  '16967',
#  '3389',
#  '12870',
#  '9850',
#  '11036',
#  '1616',
#  '13477',
#  '11733',
#  '8388',
#  ...]

# %%
"7" in a
# Out:
# False

# %%
# Out:
# 'Test01_experiment_2018-09-03-04-16-16'
