# %%
from datetime import datetime
import re
import os
import json
import sys

import pandas as pd

# %%
# helper functions

# https://stackoverflow.com/questions/17060039/split-string-at-nth-occurrence-of-a-given-character
def splitn(string, spliton, n):
    """split 'string' on nth occurence of 'spliton'
    """
    groups = string.split(spliton)
    return spliton.join(groups[:n]), spliton.join(groups[n:])


def ms_delta(t):
    """convert timedelta t to milliseconds
    """
    return round(t.seconds * 1000 + t.microseconds / 1000)

# %%
# settings and configuration

# print output for debugging
verbose = False

# directory that contains *only* log files
logpath = "logs/"

# these are columns that define a single trial
columns = ['Participant',            # participant id (P01, P02, ...)
#            'Order',                  # what condition order this particpant did 
           'Condition',              # what condition this particpant did (typing, pointing, posture)
           'Block',                  # upto 3
           'Sequence',               # upto 14
           'Trial',                  # upto 7
           'Mode_Switching_Time',    #time in ms to switch from previous task to this one
           'Trial_Completion_Time',  #time in ms
           'Errors',                 # number of errors
            ]

# time format in the example log is like 2018/07/10-16:41:54.4902
# see https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior
# time_format = '%Y/%m/%d-%H:%M:%S.%f'
time_format = '%Y-%m-%d %H:%M:%S.%f'

# %%
# parsing loop

# open the output datafile and write the column headers
data = open('data.csv', 'w')
data.write(','.join(columns) + '\n')

logpath = "/home/nchhibbe/sketchbook/typealike/log/test/"
# each log in the directory will be processed, order shouldn't matter
logfns = os.listdir(logpath)
print(logfns)

modeSwitch=False
currentTaskFirstAttempt=0;
previousTaskEndTime=0;
nextTaskStart=False;

for logfn in logfns:

    print(logfn)
    

    log = open(logpath + logfn, 'r')
    
    # initalize a dictionary of values we'll write to the datafile
    d = {e:0 for e in columns}
    
    # initalize temporary values
    trial_start_time = 0

    # we'll go through line-by-line
    line_num = 0
    for row in log:   
        
        # print some feedback
        line_num += 1
        if line_num % 1000 == 0: print(' {}'.format(line_num))
            
        # could identify and i log comments here ...
        if row[0] == '#':             
            continue
        
        # split the line
        rr = row.strip().split(',')
        t = str(datetime.fromtimestamp(int(rr[0])/1000))
        if "." not in t:
            t+=".0"
        # every line must start with: timestamp, type, subtype
        ts = datetime.strptime(t, time_format)
        et = (rr[1], rr[2])
        
        # input events are special
        if et[0] == 'M' or et[0] == 'keypressed':
            # rest of line is CSV
            pass
        if et[0] == 'I':
            if modeSwitch and nextTaskStart:
                currentTaskFirstAttempt = int(rr[0])
                modeSwitch=False
            pass
            
        else:
            # resplit on 3rd delimiters (json has commas too)
            r = splitn(row, ',', 3)
            
            try:
                # parse the json event data
                print(r[1])
                ed = json.loads(r[1])
            except Exception as e:
                print('error parsing json event data on row{}: {}\n{}'.format(rownum, r, e))
 
            # handle experiment 
            if et == ('E', 'experiment'):
                d['Participant'] = ed['participantid']
            
            elif et == ('E', 'block'):
                # block is just a number
                d['Block'] = int(ed['num'])

            elif et == ('E', 'sequence'):
#                 print(ed)
#                 if ed['type'] == "start":
#                     d['Order'] = ed['taskOrder']
                # sequence is a number
                d['Sequence'] = int(ed['num'])
                
#             elif et == ('E', 'task'):
#                 # check if this task event is an error
#                 if ed['action'] == 'failure':
#                     d['Errors'] += 1
                
            elif et == ('E', 'trial'):
                # trials should be 1, 2, 3, ... for each sequence
                d['Trial'] = int(ed['num'])
                d['Condition'] = ed['targetType']
                
                if ed['type'] == "start":
                    nextTaskStart = True
                # if not first trial, calculate any trial stats and save to log
                if ed['type'] == "end":
                    d['Mode_Switching_Time'] = currentTaskFirstAttempt- previousTaskEndTime
                    previousTaskEndTime = int(rr[0])
                    modeSwitch = True
                    nextTaskStart = False
                    print(ed['action'])
                    if ed['action'] == 'miss':
                        d['Errors'] = 1

                    # calculate stats
                    # trial_duration = ts - trial_start_time
#                     print(ed['duration'][2:7])
#                     print(ed['duration'][2:7].replace(".",""))
                    dur = re.search(r'\d+.?\d*', ed['duration'])
                    d['Trial_Completion_Time'] = int(dur.group().replace(".",""))# ms_delta(trial_duration)
                    
                    # save to log
                    datarow = [d[k] for k in columns]
                    datarow_csv = ','.join(str(i) for i in datarow)
#                     print(datarow_csv)
                    data.write(datarow_csv + '\n')
                    
                    # reset trial counters or accumulators
                    d['Errors'] = 0
                
                trial_start_time = ts


data.close()
# Out:
# ['P00_experiment_2018-08-29-03-08-11.txt']
# P00_experiment_2018-08-29-03-08-11.txt
# {"type":"start","participantid":"P00","study":"two","datetime":"2018-08-29T07:08:11.705Z"}
#
# {"type":"start","num":"0","numBlocks":"3","datetime":"2018-08-29T07:08:11.729Z"}
#
# {"type":"start","blockNum":"0","num":"0","taskOrder":"0","datetime":"2018-08-29T07:08:11.739Z"}
#
# {"type":"start","label":"Royal","targetType":"word","sequenceNum":"0","blockNum":"0","num":"0","startX":"1312","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:11.740Z"}
#
# {"type":"end","label":"Royal","action":"hit","currScore":"0","targetType":"word","num":"0","sequenceNum":"0","blockNum":"0","datetime":"2018-08-29T07:08:15.057Z","duration":"PT3.317S"}
#
# hit
# {"type":"start","label":"(i<5)","targetType":"equation","sequenceNum":"0","blockNum":"0","num":"1","startX":"1434","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:15.088Z"}
#
# {"type":"end","label":"(i<5)","action":"hit","currScore":"10","targetType":"equation","num":"1","sequenceNum":"0","blockNum":"0","datetime":"2018-08-29T07:08:18.812Z","duration":"PT3.724S"}
#
# hit
# {"type":"start","label":"F12","targetType":"shortcut","sequenceNum":"0","blockNum":"0","num":"2","startX":"137","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:18.830Z"}
#
# {"type":"end","label":"F12","action":"hit","currScore":"20","targetType":"shortcut","num":"2","sequenceNum":"0","blockNum":"0","datetime":"2018-08-29T07:08:25.501Z","duration":"PT6.671S"}
#
# hit
# {"type":"start","label":"std::","targetType":"equation","sequenceNum":"0","blockNum":"0","num":"3","startX":"1402","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:25.516Z"}
#
# {"type":"end","label":"std::","action":"hit","currScore":"30","targetType":"equation","num":"3","sequenceNum":"0","blockNum":"0","datetime":"2018-08-29T07:08:27.786Z","duration":"PT2.27S"}
#
# hit
# {"type":"start","label":"lefthandlock.png","targetType":"posture","sequenceNum":"0","blockNum":"0","num":"4","startX":"1431","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:27.817Z"}
#
# {"type":"end","label":"lefthandlock.png","action":"hit","currScore":"40","targetType":"posture","num":"4","sequenceNum":"0","blockNum":"0","datetime":"2018-08-29T07:08:27.872Z","duration":"PT0.055S"}
#
# hit
# {"type":"start","label":"grasp","targetType":"word","sequenceNum":"0","blockNum":"0","num":"5","startX":"682","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:27.873Z"}
#
# {"type":"end","num":"1","datetime":"2018-08-29T07:08:27.913Z","duration":"PT16.174S"}
#
# {"type":"start","blockNum":"0","num":"1","taskOrder":"1","datetime":"2018-08-29T07:08:27.914Z"}
#
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"1","blockNum":"0","num":"0","startX":"1616","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:27.915Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"50","targetType":"click","num":"0","sequenceNum":"1","blockNum":"0","datetime":"2018-08-29T07:08:32.137Z","duration":"PT4.222S"}
#
# hit
# {"type":"start","label":"privy","targetType":"word","sequenceNum":"1","blockNum":"0","num":"1","startX":"1501","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:32.147Z"}
#
# {"type":"end","label":"privy","action":"hit","currScore":"60","targetType":"word","num":"1","sequenceNum":"1","blockNum":"0","datetime":"2018-08-29T07:08:35.386Z","duration":"PT3.239S"}
#
# hit
# {"type":"start","label":"righthandlock.png","targetType":"posture","sequenceNum":"1","blockNum":"0","num":"2","startX":"949","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:35.403Z"}
#
# {"type":"end","label":"righthandlock.png","action":"hit","currScore":"70","targetType":"posture","num":"2","sequenceNum":"1","blockNum":"0","datetime":"2018-08-29T07:08:38.736Z","duration":"PT3.333S"}
#
# hit
# {"type":"start","label":"ivory","targetType":"word","sequenceNum":"1","blockNum":"0","num":"3","startX":"1531","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:38.737Z"}
#
# {"type":"end","label":"ivory","action":"hit","currScore":"80","targetType":"word","num":"3","sequenceNum":"1","blockNum":"0","datetime":"2018-08-29T07:08:41.046Z","duration":"PT2.309S"}
#
# hit
# {"type":"start","label":"F2","targetType":"shortcut","sequenceNum":"1","blockNum":"0","num":"4","startX":"922","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:41.059Z"}
#
# {"type":"end","label":"F2","action":"hit","currScore":"90","targetType":"shortcut","num":"4","sequenceNum":"1","blockNum":"0","datetime":"2018-08-29T07:08:45.816Z","duration":"PT4.757S"}
#
# hit
# {"type":"start","label":"roast","targetType":"word","sequenceNum":"1","blockNum":"0","num":"5","startX":"1147","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:45.833Z"}
#
# {"type":"end","num":"2","datetime":"2018-08-29T07:08:45.846Z","duration":"PT17.932S"}
#
# {"type":"start","blockNum":"0","num":"2","taskOrder":"2","datetime":"2018-08-29T07:08:45.846Z"}
#
# {"type":"start","label":"craft","targetType":"word","sequenceNum":"2","blockNum":"0","num":"0","startX":"591","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:45.846Z"}
#
# {"type":"end","label":"craft","action":"hit","currScore":"100","targetType":"word","num":"0","sequenceNum":"2","blockNum":"0","datetime":"2018-08-29T07:08:48.169Z","duration":"PT2.323S"}
#
# hit
# {"type":"start","label":"G","targetType":"shortcut","sequenceNum":"2","blockNum":"0","num":"1","startX":"1458","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:48.177Z"}
#
# {"type":"end","label":"G","action":"hit","currScore":"110","targetType":"shortcut","num":"1","sequenceNum":"2","blockNum":"0","datetime":"2018-08-29T07:08:49.715Z","duration":"PT1.538S"}
#
# hit
# {"type":"start","label":"i=10;","targetType":"equation","sequenceNum":"2","blockNum":"0","num":"2","startX":"1889","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:49.726Z"}
#
# {"type":"end","label":"i=10;","action":"hit","currScore":"120","targetType":"equation","num":"2","sequenceNum":"2","blockNum":"0","datetime":"2018-08-29T07:08:51.885Z","duration":"PT2.159S"}
#
# hit
# {"type":"start","label":"bothhandlock.png","targetType":"posture","sequenceNum":"2","blockNum":"0","num":"3","startX":"619","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:51.903Z"}
#
# {"type":"end","label":"bothhandlock.png","action":"hit","currScore":"130","targetType":"posture","num":"3","sequenceNum":"2","blockNum":"0","datetime":"2018-08-29T07:08:52.947Z","duration":"PT1.044S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"2","blockNum":"0","num":"4","startX":"1264","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:52.948Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"140","targetType":"click","num":"4","sequenceNum":"2","blockNum":"0","datetime":"2018-08-29T07:08:55.230Z","duration":"PT2.282S"}
#
# hit
# {"type":"start","label":"Today","targetType":"word","sequenceNum":"2","blockNum":"0","num":"5","startX":"34","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:55.243Z"}
#
# {"type":"end","num":"3","datetime":"2018-08-29T07:08:55.257Z","duration":"PT9.411S"}
#
# {"type":"start","blockNum":"0","num":"3","taskOrder":"3","datetime":"2018-08-29T07:08:55.257Z"}
#
# {"type":"start","label":"olive","targetType":"word","sequenceNum":"3","blockNum":"0","num":"0","startX":"1511","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:55.257Z"}
#
# {"type":"end","label":"olive","action":"hit","currScore":"150","targetType":"word","num":"0","sequenceNum":"3","blockNum":"0","datetime":"2018-08-29T07:08:57.828Z","duration":"PT2.571S"}
#
# hit
# {"type":"start","label":"Won't","targetType":"word","sequenceNum":"3","blockNum":"0","num":"1","startX":"1523","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:08:57.838Z"}
#
# {"type":"end","label":"Won't","action":"hit","currScore":"160","targetType":"word","num":"1","sequenceNum":"3","blockNum":"0","datetime":"2018-08-29T07:09:00.118Z","duration":"PT2.28S"}
#
# hit
# {"type":"start","label":"lefthandpinch.png","targetType":"posture","sequenceNum":"3","blockNum":"0","num":"2","startX":"1337","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:00.133Z"}
#
# {"type":"end","label":"lefthandpinch.png","action":"hit","currScore":"170","targetType":"posture","num":"2","sequenceNum":"3","blockNum":"0","datetime":"2018-08-29T07:09:06.577Z","duration":"PT6.444S"}
#
# hit
# {"type":"start","label":"blade","targetType":"word","sequenceNum":"3","blockNum":"0","num":"3","startX":"200","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:06.577Z"}
#
# {"type":"end","label":"blade","action":"hit","currScore":"180","targetType":"word","num":"3","sequenceNum":"3","blockNum":"0","datetime":"2018-08-29T07:09:09.149Z","duration":"PT2.572S"}
#
# hit
# {"type":"start","label":"F2","targetType":"shortcut","sequenceNum":"3","blockNum":"0","num":"4","startX":"1836","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:09.166Z"}
#
# {"type":"end","label":"F2","action":"hit","currScore":"190","targetType":"shortcut","num":"4","sequenceNum":"3","blockNum":"0","datetime":"2018-08-29T07:09:11.126Z","duration":"PT1.96S"}
#
# hit
# {"type":"start","label":"added","targetType":"word","sequenceNum":"3","blockNum":"0","num":"5","startX":"1802","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:11.140Z"}
#
# {"type":"end","num":"4","datetime":"2018-08-29T07:09:11.158Z","duration":"PT15.901S"}
#
# {"type":"start","blockNum":"0","num":"4","taskOrder":"4","datetime":"2018-08-29T07:09:11.158Z"}
#
# {"type":"start","label":"(i<5)","targetType":"equation","sequenceNum":"4","blockNum":"0","num":"0","startX":"1316","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:11.158Z"}
#
# {"type":"end","label":"(i<5)","action":"hit","currScore":"200","targetType":"equation","num":"0","sequenceNum":"4","blockNum":"0","datetime":"2018-08-29T07:09:14.087Z","duration":"PT2.929S"}
#
# hit
# {"type":"start","label":"F4","targetType":"shortcut","sequenceNum":"4","blockNum":"0","num":"1","startX":"1510","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:14.106Z"}
#
# {"type":"end","label":"F4","action":"hit","currScore":"210","targetType":"shortcut","num":"1","sequenceNum":"4","blockNum":"0","datetime":"2018-08-29T07:09:16.077Z","duration":"PT1.971S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"4","blockNum":"0","num":"2","startX":"252","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:16.095Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"220","targetType":"click","num":"2","sequenceNum":"4","blockNum":"0","datetime":"2018-08-29T07:09:18.416Z","duration":"PT2.321S"}
#
# hit
# {"type":"start","label":"bugle","targetType":"word","sequenceNum":"4","blockNum":"0","num":"3","startX":"1048","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:18.428Z"}
#
# {"type":"end","label":"bugle","action":"hit","currScore":"230","targetType":"word","num":"3","sequenceNum":"4","blockNum":"0","datetime":"2018-08-29T07:09:20.818Z","duration":"PT2.39S"}
#
# hit
# {"type":"start","label":"righthandpinch.png","targetType":"posture","sequenceNum":"4","blockNum":"0","num":"4","startX":"1701","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:20.824Z"}
#
# {"type":"end","label":"righthandpinch.png","action":"hit","currScore":"240","targetType":"posture","num":"4","sequenceNum":"4","blockNum":"0","datetime":"2018-08-29T07:09:23.257Z","duration":"PT2.433S"}
#
# hit
# {"type":"start","label":"funny","targetType":"word","sequenceNum":"4","blockNum":"0","num":"5","startX":"1455","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:23.258Z"}
#
# {"type":"end","num":"5","datetime":"2018-08-29T07:09:23.270Z","duration":"PT12.112S"}
#
# {"type":"start","blockNum":"0","num":"5","taskOrder":"5","datetime":"2018-08-29T07:09:23.270Z"}
#
# {"type":"start","label":"#undef","targetType":"equation","sequenceNum":"5","blockNum":"0","num":"0","startX":"786","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:23.270Z"}
#
# {"type":"end","label":"#undef","action":"hit","currScore":"250","targetType":"equation","num":"0","sequenceNum":"5","blockNum":"0","datetime":"2018-08-29T07:09:25.796Z","duration":"PT2.526S"}
#
# hit
# {"type":"start","label":"up","targetType":"shortcut","sequenceNum":"5","blockNum":"0","num":"1","startX":"531","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:25.806Z"}
#
# {"type":"end","label":"up","action":"hit","currScore":"260","targetType":"shortcut","num":"1","sequenceNum":"5","blockNum":"0","datetime":"2018-08-29T07:09:29.145Z","duration":"PT3.339S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"5","blockNum":"0","num":"2","startX":"1223","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:29.153Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"270","targetType":"click","num":"2","sequenceNum":"5","blockNum":"0","datetime":"2018-08-29T07:09:32.212Z","duration":"PT3.059S"}
#
# hit
# {"type":"start","label":"(3*4)","targetType":"equation","sequenceNum":"5","blockNum":"0","num":"3","startX":"1185","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:32.221Z"}
#
# {"type":"end","label":"(3*4)","action":"hit","currScore":"280","targetType":"equation","num":"3","sequenceNum":"5","blockNum":"0","datetime":"2018-08-29T07:09:35.825Z","duration":"PT3.604S"}
#
# hit
# {"type":"start","label":"bothhandpinch.png","targetType":"posture","sequenceNum":"5","blockNum":"0","num":"4","startX":"1534","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:35.846Z"}
#
# {"type":"end","label":"bothhandpinch.png","action":"hit","currScore":"290","targetType":"posture","num":"4","sequenceNum":"5","blockNum":"0","datetime":"2018-08-29T07:09:36.985Z","duration":"PT1.139S"}
#
# hit
# {"type":"start","label":"aloof","targetType":"word","sequenceNum":"5","blockNum":"0","num":"5","startX":"1221","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:36.985Z"}
#
# {"type":"end","num":"6","datetime":"2018-08-29T07:09:37Z","duration":"PT13.73S"}
#
# {"type":"start","blockNum":"0","num":"6","taskOrder":"6","datetime":"2018-08-29T07:09:37Z"}
#
# {"type":"start","label":"title","targetType":"word","sequenceNum":"6","blockNum":"0","num":"0","startX":"1601","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:37Z"}
#
# {"type":"end","label":"title","action":"hit","currScore":"300","targetType":"word","num":"0","sequenceNum":"6","blockNum":"0","datetime":"2018-08-29T07:09:40.628Z","duration":"PT3.628S"}
#
# hit
# {"type":"start","label":"bothhandcover.png","targetType":"posture","sequenceNum":"6","blockNum":"0","num":"1","startX":"1000","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:40.646Z"}
#
# {"type":"end","label":"bothhandcover.png","action":"hit","currScore":"310","targetType":"posture","num":"1","sequenceNum":"6","blockNum":"0","datetime":"2018-08-29T07:09:41.870Z","duration":"PT1.224S"}
#
# hit
# {"type":"start","label":"drawn","targetType":"word","sequenceNum":"6","blockNum":"0","num":"2","startX":"477","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:41.871Z"}
#
# {"type":"end","label":"drawn","action":"hit","currScore":"320","targetType":"word","num":"2","sequenceNum":"6","blockNum":"0","datetime":"2018-08-29T07:09:46.405Z","duration":"PT4.534S"}
#
# hit
# {"type":"start","label":"(3*4)","targetType":"equation","sequenceNum":"6","blockNum":"0","num":"3","startX":"1379","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:46.419Z"}
#
# {"type":"end","label":"(3*4)","action":"hit","currScore":"330","targetType":"equation","num":"3","sequenceNum":"6","blockNum":"0","datetime":"2018-08-29T07:09:50.173Z","duration":"PT3.754S"}
#
# hit
# {"type":"start","label":"F12","targetType":"shortcut","sequenceNum":"6","blockNum":"0","num":"4","startX":"1541","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:50.188Z"}
#
# {"type":"end","label":"F12","action":"hit","currScore":"340","targetType":"shortcut","num":"4","sequenceNum":"6","blockNum":"0","datetime":"2018-08-29T07:09:53.314Z","duration":"PT3.126S"}
#
# hit
# {"type":"start","label":"Alone","targetType":"word","sequenceNum":"6","blockNum":"0","num":"5","startX":"683","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:53.330Z"}
#
# {"type":"end","num":"7","datetime":"2018-08-29T07:09:53.346Z","duration":"PT16.346S"}
#
# {"type":"start","blockNum":"0","num":"7","taskOrder":"7","datetime":"2018-08-29T07:09:53.347Z"}
#
# {"type":"start","label":"dined","targetType":"word","sequenceNum":"7","blockNum":"0","num":"0","startX":"485","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:53.348Z"}
#
# {"type":"end","label":"dined","action":"hit","currScore":"350","targetType":"word","num":"0","sequenceNum":"7","blockNum":"0","datetime":"2018-08-29T07:09:55.687Z","duration":"PT2.339S"}
#
# hit
# {"type":"start","label":"Alone","targetType":"word","sequenceNum":"7","blockNum":"0","num":"1","startX":"108","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:55.700Z"}
#
# {"type":"end","label":"Alone","action":"hit","currScore":"360","targetType":"word","num":"1","sequenceNum":"7","blockNum":"0","datetime":"2018-08-29T07:09:58.151Z","duration":"PT2.451S"}
#
# hit
# {"type":"start","label":"F7","targetType":"shortcut","sequenceNum":"7","blockNum":"0","num":"2","startX":"972","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:09:58.163Z"}
#
# {"type":"end","label":"F7","action":"hit","currScore":"370","targetType":"shortcut","num":"2","sequenceNum":"7","blockNum":"0","datetime":"2018-08-29T07:10:01.498Z","duration":"PT3.335S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"7","blockNum":"0","num":"3","startX":"1581","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:01.514Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"380","targetType":"click","num":"3","sequenceNum":"7","blockNum":"0","datetime":"2018-08-29T07:10:06.644Z","duration":"PT5.13S"}
#
# hit
# {"type":"start","label":"lefthandfist.png","targetType":"posture","sequenceNum":"7","blockNum":"0","num":"4","startX":"1660","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:06.651Z"}
#
# {"type":"end","label":"lefthandfist.png","action":"hit","currScore":"390","targetType":"posture","num":"4","sequenceNum":"7","blockNum":"0","datetime":"2018-08-29T07:10:08.771Z","duration":"PT2.12S"}
#
# hit
# {"type":"start","label":"grown","targetType":"word","sequenceNum":"7","blockNum":"0","num":"5","startX":"90","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:08.772Z"}
#
# {"type":"end","num":"8","datetime":"2018-08-29T07:10:08.783Z","duration":"PT15.436S"}
#
# {"type":"start","blockNum":"0","num":"8","taskOrder":"8","datetime":"2018-08-29T07:10:08.784Z"}
#
# {"type":"start","label":"a+b=c","targetType":"equation","sequenceNum":"8","blockNum":"0","num":"0","startX":"1704","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:08.784Z"}
#
# {"type":"end","label":"a+b=c","action":"hit","currScore":"400","targetType":"equation","num":"0","sequenceNum":"8","blockNum":"0","datetime":"2018-08-29T07:10:11.583Z","duration":"PT2.799S"}
#
# hit
# {"type":"start","label":"righthandfist.png","targetType":"posture","sequenceNum":"8","blockNum":"0","num":"1","startX":"1395","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:11.599Z"}
#
# {"type":"end","label":"righthandfist.png","action":"miss","currScore":"410","targetType":"posture","num":"1","sequenceNum":"8","blockNum":"0","datetime":"2018-08-29T07:10:19.995Z","duration":"PT8.396S"}
#
# miss
# {"type":"start","label":"yours","targetType":"word","sequenceNum":"8","blockNum":"0","num":"2","startX":"1381","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:19.996Z"}
#
# {"type":"end","label":"yours","action":"hit","currScore":"405","targetType":"word","num":"2","sequenceNum":"8","blockNum":"0","datetime":"2018-08-29T07:10:25.436Z","duration":"PT5.44S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"8","blockNum":"0","num":"3","startX":"1823","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:25.446Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"415","targetType":"click","num":"3","sequenceNum":"8","blockNum":"0","datetime":"2018-08-29T07:10:28.394Z","duration":"PT2.948S"}
#
# hit
# {"type":"start","label":"F5","targetType":"shortcut","sequenceNum":"8","blockNum":"0","num":"4","startX":"807","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:28.408Z"}
#
#  1000
# {"type":"end","label":"F5","action":"hit","currScore":"425","targetType":"shortcut","num":"4","sequenceNum":"8","blockNum":"0","datetime":"2018-08-29T07:10:30.449Z","duration":"PT2.041S"}
#
# hit
# {"type":"start","label":"faith","targetType":"word","sequenceNum":"8","blockNum":"0","num":"5","startX":"360","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:30.462Z"}
#
# {"type":"end","num":"9","datetime":"2018-08-29T07:10:30.479Z","duration":"PT21.695S"}
#
# {"type":"start","blockNum":"0","num":"9","taskOrder":"9","datetime":"2018-08-29T07:10:30.480Z"}
#
# {"type":"start","label":"4!=24","targetType":"equation","sequenceNum":"9","blockNum":"0","num":"0","startX":"1377","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:30.480Z"}
#
# {"type":"end","label":"4!=24","action":"hit","currScore":"435","targetType":"equation","num":"0","sequenceNum":"9","blockNum":"0","datetime":"2018-08-29T07:10:34.864Z","duration":"PT4.384S"}
#
# hit
# {"type":"start","label":"i=10;","targetType":"equation","sequenceNum":"9","blockNum":"0","num":"1","startX":"761","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:34.879Z"}
#
# {"type":"end","label":"i=10;","action":"hit","currScore":"445","targetType":"equation","num":"1","sequenceNum":"9","blockNum":"0","datetime":"2018-08-29T07:10:37.048Z","duration":"PT2.169S"}
#
# hit
# {"type":"start","label":"down","targetType":"shortcut","sequenceNum":"9","blockNum":"0","num":"2","startX":"1775","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:37.063Z"}
#
# {"type":"end","label":"down","action":"hit","currScore":"455","targetType":"shortcut","num":"2","sequenceNum":"9","blockNum":"0","datetime":"2018-08-29T07:10:38.417Z","duration":"PT1.354S"}
#
# hit
# {"type":"start","label":"e=mc2","targetType":"equation","sequenceNum":"9","blockNum":"0","num":"3","startX":"54","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:38.432Z"}
#
# {"type":"end","label":"e=mc2","action":"hit","currScore":"465","targetType":"equation","num":"3","sequenceNum":"9","blockNum":"0","datetime":"2018-08-29T07:10:40.778Z","duration":"PT2.346S"}
#
# hit
# {"type":"start","label":"bothhandfist.png","targetType":"posture","sequenceNum":"9","blockNum":"0","num":"4","startX":"484","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:40.795Z"}
#
# {"type":"end","label":"bothhandfist.png","action":"hit","currScore":"475","targetType":"posture","num":"4","sequenceNum":"9","blockNum":"0","datetime":"2018-08-29T07:10:41.760Z","duration":"PT0.965S"}
#
# hit
# {"type":"start","label":"Macon","targetType":"word","sequenceNum":"9","blockNum":"0","num":"5","startX":"1682","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:41.761Z"}
#
# {"type":"end","num":"10","datetime":"2018-08-29T07:10:41.777Z","duration":"PT11.297S"}
#
# {"type":"start","blockNum":"0","num":"10","taskOrder":"10","datetime":"2018-08-29T07:10:41.777Z"}
#
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"10","blockNum":"0","num":"0","startX":"256","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:41.777Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"485","targetType":"click","num":"0","sequenceNum":"10","blockNum":"0","datetime":"2018-08-29T07:10:45.030Z","duration":"PT3.253S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"10","blockNum":"0","num":"1","startX":"707","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:45.045Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"495","targetType":"click","num":"1","sequenceNum":"10","blockNum":"0","datetime":"2018-08-29T07:10:50.278Z","duration":"PT5.233S"}
#
# hit
# {"type":"start","label":"upperlefthandlock.png","targetType":"posture","sequenceNum":"10","blockNum":"0","num":"2","startX":"1214","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:50.293Z"}
#
# {"type":"end","label":"upperlefthandlock.png","action":"miss","currScore":"505","targetType":"posture","num":"2","sequenceNum":"10","blockNum":"0","datetime":"2018-08-29T07:10:58.743Z","duration":"PT8.45S"}
#
# miss
# {"type":"start","label":"4!=24","targetType":"equation","sequenceNum":"10","blockNum":"0","num":"3","startX":"698","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:10:58.745Z"}
#
# {"type":"end","label":"4!=24","action":"hit","currScore":"500","targetType":"equation","num":"3","sequenceNum":"10","blockNum":"0","datetime":"2018-08-29T07:11:01.705Z","duration":"PT2.96S"}
#
# hit
# {"type":"start","label":"F4","targetType":"shortcut","sequenceNum":"10","blockNum":"0","num":"4","startX":"467","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:01.719Z"}
#
# {"type":"end","label":"F4","action":"hit","currScore":"510","targetType":"shortcut","num":"4","sequenceNum":"10","blockNum":"0","datetime":"2018-08-29T07:11:03.189Z","duration":"PT1.47S"}
#
# hit
# {"type":"start","label":"Blois","targetType":"word","sequenceNum":"10","blockNum":"0","num":"5","startX":"1557","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:03.205Z"}
#
# {"type":"end","num":"11","datetime":"2018-08-29T07:11:03.220Z","duration":"PT21.443S"}
#
# {"type":"start","blockNum":"0","num":"11","taskOrder":"11","datetime":"2018-08-29T07:11:03.221Z"}
#
# {"type":"start","label":"stall","targetType":"word","sequenceNum":"11","blockNum":"0","num":"0","startX":"858","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:03.221Z"}
#
# {"type":"end","label":"stall","action":"hit","currScore":"520","targetType":"word","num":"0","sequenceNum":"11","blockNum":"0","datetime":"2018-08-29T07:11:06.491Z","duration":"PT3.27S"}
#
# hit
# {"type":"start","label":"a+b=c","targetType":"equation","sequenceNum":"11","blockNum":"0","num":"1","startX":"291","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:06.506Z"}
#
# {"type":"end","label":"a+b=c","action":"hit","currScore":"530","targetType":"equation","num":"1","sequenceNum":"11","blockNum":"0","datetime":"2018-08-29T07:11:09.430Z","duration":"PT2.924S"}
#
# hit
# {"type":"start","label":"E","targetType":"shortcut","sequenceNum":"11","blockNum":"0","num":"2","startX":"1728","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:09.445Z"}
#
# {"type":"end","label":"E","action":"hit","currScore":"540","targetType":"shortcut","num":"2","sequenceNum":"11","blockNum":"0","datetime":"2018-08-29T07:11:11.208Z","duration":"PT1.763S"}
#
# hit
# {"type":"start","label":"e=mc2","targetType":"equation","sequenceNum":"11","blockNum":"0","num":"3","startX":"1052","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:11.222Z"}
#
# {"type":"end","label":"e=mc2","action":"hit","currScore":"550","targetType":"equation","num":"3","sequenceNum":"11","blockNum":"0","datetime":"2018-08-29T07:11:14.340Z","duration":"PT3.118S"}
#
# hit
# {"type":"start","label":"upperrighthandlock.png","targetType":"posture","sequenceNum":"11","blockNum":"0","num":"4","startX":"381","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:14.350Z"}
#
# {"type":"end","label":"upperrighthandlock.png","action":"hit","currScore":"560","targetType":"posture","num":"4","sequenceNum":"11","blockNum":"0","datetime":"2018-08-29T07:11:15.523Z","duration":"PT1.173S"}
#
# hit
# {"type":"start","label":"About","targetType":"word","sequenceNum":"11","blockNum":"0","num":"5","startX":"1633","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:15.523Z"}
#
# {"type":"end","num":"12","datetime":"2018-08-29T07:11:15.538Z","duration":"PT12.317S"}
#
# {"type":"start","blockNum":"0","num":"12","taskOrder":"12","datetime":"2018-08-29T07:11:15.538Z"}
#
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"12","blockNum":"0","num":"0","startX":"79","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:15.538Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"570","targetType":"click","num":"0","sequenceNum":"12","blockNum":"0","datetime":"2018-08-29T07:11:18.529Z","duration":"PT2.991S"}
#
# hit
# {"type":"start","label":"(i<5)","targetType":"equation","sequenceNum":"12","blockNum":"0","num":"1","startX":"1484","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:18.543Z"}
#
# {"type":"end","label":"(i<5)","action":"hit","currScore":"580","targetType":"equation","num":"1","sequenceNum":"12","blockNum":"0","datetime":"2018-08-29T07:11:23.227Z","duration":"PT4.684S"}
#
# hit
# {"type":"start","label":"upperbothhandlock.png","targetType":"posture","sequenceNum":"12","blockNum":"0","num":"2","startX":"1500","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:23.239Z"}
#
# {"type":"end","label":"upperbothhandlock.png","action":"hit","currScore":"590","targetType":"posture","num":"2","sequenceNum":"12","blockNum":"0","datetime":"2018-08-29T07:11:24.145Z","duration":"PT0.906S"}
#
# hit
# {"type":"start","label":"()?:","targetType":"equation","sequenceNum":"12","blockNum":"0","num":"3","startX":"1083","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:24.146Z"}
#
# {"type":"end","label":"()?:","action":"hit","currScore":"600","targetType":"equation","num":"3","sequenceNum":"12","blockNum":"0","datetime":"2018-08-29T07:11:27.422Z","duration":"PT3.276S"}
#
# hit
# {"type":"start","label":"D","targetType":"shortcut","sequenceNum":"12","blockNum":"0","num":"4","startX":"252","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:27.438Z"}
#
# {"type":"end","label":"D","action":"hit","currScore":"610","targetType":"shortcut","num":"4","sequenceNum":"12","blockNum":"0","datetime":"2018-08-29T07:11:28.689Z","duration":"PT1.251S"}
#
# hit
# {"type":"start","label":"fists","targetType":"word","sequenceNum":"12","blockNum":"0","num":"5","startX":"1117","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:28.703Z"}
#
# {"type":"end","num":"13","datetime":"2018-08-29T07:11:28.718Z","duration":"PT13.18S"}
#
# {"type":"start","blockNum":"0","num":"13","taskOrder":"13","datetime":"2018-08-29T07:11:28.718Z"}
#
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"13","blockNum":"0","num":"0","startX":"1365","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:28.718Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"620","targetType":"click","num":"0","sequenceNum":"13","blockNum":"0","datetime":"2018-08-29T07:11:30.925Z","duration":"PT2.207S"}
#
# hit
# {"type":"start","label":"Y","targetType":"shortcut","sequenceNum":"13","blockNum":"0","num":"1","startX":"585","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:30.939Z"}
#
# {"type":"end","label":"Y","action":"hit","currScore":"630","targetType":"shortcut","num":"1","sequenceNum":"13","blockNum":"0","datetime":"2018-08-29T07:11:32.959Z","duration":"PT2.02S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"13","blockNum":"0","num":"2","startX":"1187","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:32.972Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"640","targetType":"click","num":"2","sequenceNum":"13","blockNum":"0","datetime":"2018-08-29T07:11:36.309Z","duration":"PT3.337S"}
#
# hit
# {"type":"start","label":"5%2=1","targetType":"equation","sequenceNum":"13","blockNum":"0","num":"3","startX":"217","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:36.318Z"}
#
# {"type":"end","label":"5%2=1","action":"hit","currScore":"650","targetType":"equation","num":"3","sequenceNum":"13","blockNum":"0","datetime":"2018-08-29T07:11:41.319Z","duration":"PT5.001S"}
#
# hit
# {"type":"start","label":"birdhand.png","targetType":"posture","sequenceNum":"13","blockNum":"0","num":"4","startX":"1366","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:41.335Z"}
#
# {"type":"end","label":"birdhand.png","action":"hit","currScore":"660","targetType":"posture","num":"4","sequenceNum":"13","blockNum":"0","datetime":"2018-08-29T07:11:42.494Z","duration":"PT1.159S"}
#
# hit
# {"type":"start","label":"saint","targetType":"word","sequenceNum":"13","blockNum":"0","num":"5","startX":"1491","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:42.494Z"}
#
# {"type":"end","num":"13","datetime":"2018-08-29T07:11:42.507Z","duration":"PT13.789S"}
#
# {"type":"end","num":"1","datetime":"2018-08-29T07:11:42.507Z","duration":"PT3M30.778S"}
#
# {"type":"start","num":"1","numBlocks":"3","datetime":"2018-08-29T07:11:53.848Z"}
#
# {"type":"start","blockNum":"1","num":"0","taskOrder":"0","datetime":"2018-08-29T07:11:53.848Z"}
#
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"0","blockNum":"1","num":"0","startX":"670","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:53.848Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"670","targetType":"click","num":"0","sequenceNum":"0","blockNum":"1","datetime":"2018-08-29T07:11:56.511Z","duration":"PT2.663S"}
#
# hit
# {"type":"start","label":"named","targetType":"word","sequenceNum":"0","blockNum":"1","num":"1","startX":"1722","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:56.522Z"}
#
# {"type":"end","label":"named","action":"hit","currScore":"680","targetType":"word","num":"1","sequenceNum":"0","blockNum":"1","datetime":"2018-08-29T07:11:58.117Z","duration":"PT1.595S"}
#
# hit
# {"type":"start","label":"F3","targetType":"shortcut","sequenceNum":"0","blockNum":"1","num":"2","startX":"592","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:11:58.128Z"}
#
# {"type":"end","label":"F3","action":"hit","currScore":"690","targetType":"shortcut","num":"2","sequenceNum":"0","blockNum":"1","datetime":"2018-08-29T07:12:00.035Z","duration":"PT1.907S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"0","blockNum":"1","num":"3","startX":"54","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:00.051Z"}
#
#  2000
# {"type":"end","label":"click me","action":"hit","currScore":"700","targetType":"click","num":"3","sequenceNum":"0","blockNum":"1","datetime":"2018-08-29T07:12:02.227Z","duration":"PT2.176S"}
#
# hit
# {"type":"start","label":"lefthandlock.png","targetType":"posture","sequenceNum":"0","blockNum":"1","num":"4","startX":"620","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:02.237Z"}
#
# {"type":"end","label":"lefthandlock.png","action":"hit","currScore":"710","targetType":"posture","num":"4","sequenceNum":"0","blockNum":"1","datetime":"2018-08-29T07:12:02.259Z","duration":"PT0.022S"}
#
# hit
# {"type":"start","label":"Dutch","targetType":"word","sequenceNum":"0","blockNum":"1","num":"5","startX":"733","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:02.260Z"}
#
# {"type":"end","num":"1","datetime":"2018-08-29T07:12:02.283Z","duration":"PT8.435S"}
#
# {"type":"start","blockNum":"1","num":"1","taskOrder":"1","datetime":"2018-08-29T07:12:02.283Z"}
#
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"1","blockNum":"1","num":"0","startX":"92","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:02.283Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"720","targetType":"click","num":"0","sequenceNum":"1","blockNum":"1","datetime":"2018-08-29T07:12:03.721Z","duration":"PT1.438S"}
#
# hit
# {"type":"start","label":"righthandlock.png","targetType":"posture","sequenceNum":"1","blockNum":"1","num":"1","startX":"1527","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:03.734Z"}
#
# {"type":"end","label":"righthandlock.png","action":"hit","currScore":"730","targetType":"posture","num":"1","sequenceNum":"1","blockNum":"1","datetime":"2018-08-29T07:12:04.939Z","duration":"PT1.205S"}
#
# hit
# {"type":"start","label":"click me","targetType":"click","sequenceNum":"1","blockNum":"1","num":"2","startX":"353","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:04.940Z"}
#
# {"type":"end","label":"click me","action":"hit","currScore":"740","targetType":"click","num":"2","sequenceNum":"1","blockNum":"1","datetime":"2018-08-29T07:12:07.481Z","duration":"PT2.541S"}
#
# hit
# {"type":"start","label":"began","targetType":"word","sequenceNum":"1","blockNum":"1","num":"3","startX":"432","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:07.496Z"}
#
# {"type":"end","label":"began","action":"hit","currScore":"750","targetType":"word","num":"3","sequenceNum":"1","blockNum":"1","datetime":"2018-08-29T07:12:09.237Z","duration":"PT1.741S"}
#
# hit
# {"type":"start","label":"X","targetType":"shortcut","sequenceNum":"1","blockNum":"1","num":"4","startX":"1042","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:09.250Z"}
#
# {"type":"end","label":"X","action":"hit","currScore":"760","targetType":"shortcut","num":"4","sequenceNum":"1","blockNum":"1","datetime":"2018-08-29T07:12:11.635Z","duration":"PT2.385S"}
#
# hit
# {"type":"start","label":"chaos","targetType":"word","sequenceNum":"1","blockNum":"1","num":"5","startX":"479","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:11.648Z"}
#
# {"type":"end","num":"2","datetime":"2018-08-29T07:12:11.665Z","duration":"PT9.382S"}
#
# {"type":"start","blockNum":"1","num":"2","taskOrder":"2","datetime":"2018-08-29T07:12:11.665Z"}
#
# {"type":"start","label":"magic","targetType":"word","sequenceNum":"2","blockNum":"1","num":"0","startX":"489","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:11.666Z"}
#
# {"type":"end","label":"magic","action":"hit","currScore":"770","targetType":"word","num":"0","sequenceNum":"2","blockNum":"1","datetime":"2018-08-29T07:12:13.935Z","duration":"PT2.269S"}
#
# hit
# {"type":"start","label":"bothhandlock.png","targetType":"posture","sequenceNum":"2","blockNum":"1","num":"1","startX":"1209","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:13.950Z"}
#
# {"type":"end","label":"bothhandlock.png","action":"hit","currScore":"780","targetType":"posture","num":"1","sequenceNum":"2","blockNum":"1","datetime":"2018-08-29T07:12:14.902Z","duration":"PT0.952S"}
#
# hit
# {"type":"start","label":"usual","targetType":"word","sequenceNum":"2","blockNum":"1","num":"2","startX":"954","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:14.902Z"}
#
# {"type":"end","label":"usual","action":"hit","currScore":"790","targetType":"word","num":"2","sequenceNum":"2","blockNum":"1","datetime":"2018-08-29T07:12:19.064Z","duration":"PT4.162S"}
#
# hit
# {"type":"start","label":"sheer","targetType":"word","sequenceNum":"2","blockNum":"1","num":"3","startX":"1039","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:19.077Z"}
#
# {"type":"end","label":"sheer","action":"miss","currScore":"800","targetType":"word","num":"3","sequenceNum":"2","blockNum":"1","datetime":"2018-08-29T07:12:27.437Z","duration":"PT8.36S"}
#
# miss
# {"type":"start","label":"N","targetType":"shortcut","sequenceNum":"2","blockNum":"1","num":"4","startX":"381","startY":"0","width":"100","height":"100","datetime":"2018-08-29T07:12:27.437Z"}
#
# {"type":"end","participantid":"P00","score":"795","datetime":"2018-08-29T07:12:29.198Z","duration":"PT4M17.493S"}

# %%
# quick data checks with pandas
df = pd.read_csv('data.csv')
df.head()
# Out:
#   Participant Condition  Block  Sequence  Trial  Mode_Switching_Time  \
# 0         P00      word      0         0      0                    0
# 1         P00  equation      0         0      1                   70
# 2         P00  shortcut      0         0      2                  129
# 3         P00  equation      0         0      3                  155
# 4         P00   posture      0         0      4                   85
#
#    Trial_Completion_Time  Errors
# 0                   3317       0
# 1                   3724       0
# 2                   6671       0
# 3                    227       0
# 4                     55       0

# %%
# check if each participant has the same number of trials per condition
df.groupby(['Participant', 'Condition']).count()['Trial_Completion_Time']
# Out:
# Participant  Condition
# P00          click        15
#              equation     17
#              posture      17
#              shortcut     16
#              word         19
# Name: Trial_Completion_Time, dtype: int64

# %%
df.groupby('Condition').mean()
# Out:
#               Block  Sequence     Trial  Mode_Switching_Time  \
# Condition
# click      0.266667  5.800000  1.466667           486.733333
# equation   0.000000  7.411765  1.764706           436.588235
# posture    0.176471  5.529412  2.764706           129.705882
# shortcut   0.125000  5.750000  2.625000           120.187500
# word       0.263158  3.631579  1.315789           661.210526
#
#            Trial_Completion_Time    Errors
# Condition
# click                2745.600000  0.000000
# equation             2936.470588  0.000000
# posture              1853.352941  0.117647
# shortcut             2248.937500  0.000000
# word                 2169.684211  0.052632

# %%
prevItem=nextItem=""
# Dictionary for (#CumulativeModeSwitchingTime, #numOfModeSwitches) for all mode switches
modeDict={
    ("word","shortcut"):[0,0],("word","click"):[0,0],("word","posture"):[0,0],("word","equation"):[0,0],
    ("shortcut","word"):[0,0],("click","word"):[0,0],("posture","word"):[0,0],("equation","word"):[0,0],
    ("shortcut","click"):[0,0],("shortcut","posture"):[0,0],("shortcut","equation"):[0,0],
    ("click","shortcut"):[0,0],("posture","shortcut"):[0,0],("equation","shortcut"):[0,0],
    ("click","posture"):[0,0],("click","equation"):[0,0],
    ("posture","click"):[0,0],("equation","click"):[0,0],
    ("posture","equation"):[0,0],("equation","posture"):[0,0],}
for index,row in df.iterrows():
    if index == 0:
        prevItem = row[1]
        pass
    if(prevItem!=row[1]):
        modeDict[(prevItem,row[1])][0] += row[5]
        modeDict[(prevItem,row[1])][1] += 1
    prevItem = row[1]

# %%
avgModeSwitchingTime={}
for index in modeDict:
#     print(modeDict[index])
    if modeDict[index][1] != 0:
        avgModeSwitchingTime[index] = modeDict[index][0]/modeDict[index][1]
    else:
        avgModeSwitchingTime[index] = 0
# Out:
# [770, 6]
# [114, 1]
# [616, 5]
# [321, 3]
# [440, 4]
# [960, 5]
# [10739, 6]
# [0, 0]
# [561, 6]
# [0, 0]
# [814, 6]
# [181, 2]
# [0, 0]
# [972, 8]
# [556, 4]
# [681, 3]
# [6277, 7]
# [0, 0]
# [5423, 4]
# [1033, 8]

# %%
616/6
# Out:
# 102.66666666666667
